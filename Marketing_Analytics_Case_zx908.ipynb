# %%
import pandas as pd
import datetime
import numpy as np
import matplotlib.pyplot as plt
import numpy
import seaborn as sns
from scipy import stats

# %% [markdown]
# ## Import datasets

# %% [markdown]
# #### 1.1 Subscibers dataset

# %%
customer = pd.read_pickle(r'subscribers')

customer
# Out:
#            subid package_type  num_weekly_services_utilized preferred_genre  \
# 162502  21724479      economy                           NaN          comedy
# 380374  23383224         base                           NaN          comedy
# 496617  26844789     enhanced                      3.362885        regional
# 356799  29417030         base                           NaN           drama
# 681701  26723159         base                      3.731089          comedy
# 284782  24810928         base                           NaN          comedy
# 192823  29726122         base                      2.049135          comedy
# 315863  20299962         base                      3.002048           drama
# 254782  24930568         base                           NaN          comedy
# 681969  23452753      economy                      2.850348           drama
# 99989   21191741          NaN                           NaN             NaN
# 290426  21361112     enhanced                           NaN          comedy
# 277565  25393847         base                      2.452687        regional
# 377093  23163827      economy                      2.876856          comedy
# 546210  26308559          NaN                           NaN             NaN
# 143042  26874196         base                           NaN          comedy
# 626743  27648682     enhanced                           NaN          comedy
# 673104  21829221     enhanced                      1.963711          comedy
# 349365  29090912         base                           NaN           drama
# 598759  21760199          NaN                           NaN             NaN
# 208223  21511732     enhanced                      2.320133          comedy
# 384799  22090440         base                      3.701633           drama
# 386250  28863903         base                      2.205253           drama
# 7506    29576692          NaN                      3.012358             NaN
# 389385  23676530         base                           NaN          comedy
# 338592  26520640     enhanced                      2.493926           drama
# 343642  29773460         base                           NaN          comedy
# 290800  20668260      economy                      4.217122           drama
# 179332  21447938         base                      2.788487           drama
# 216541  25575254      economy                           NaN          comedy
# ...          ...          ...                           ...             ...
# 582992  28111970     enhanced                      2.420285          comedy
# 117388  27161457         base                           NaN           drama
# 627527  20483363     enhanced                           NaN          comedy
# 497110  28449035         base                      3.554354          comedy
# 99888   29909208          NaN                      2.324552             NaN
# 61453   26067054         base                      2.507033           drama
# 632153  24614848         base                      2.545474        regional
# 120555  24315621         base                           NaN          comedy
# 1384    25927672          NaN                      2.935771             NaN
# 354013  26509361     enhanced                      2.876858          comedy
# 157820  29190645     enhanced                      2.764924          comedy
# 39499   22532282         base                           NaN          comedy
# 110393  26263998          NaN                           NaN             NaN
# 33596   26891485     enhanced                           NaN          comedy
# 60056   21731043     enhanced                      2.287731          comedy
# 553731  20172551         base                      2.921043          comedy
# 324200  24317364     enhanced                      2.479196          comedy
# 254294  22117405         base                           NaN          comedy
# 243775  26828621         base                      3.672180           drama
# 136817  28920930     enhanced                           NaN        regional
# 303902  22218943      economy                           NaN          comedy
# 378377  25492551         base                      2.514545          comedy
# 230734  21928274         base                           NaN           drama
# 577745  25549852     enhanced                           NaN          comedy
# 603751  25835684         base                      2.169904           drama
# 509326  21434712     enhanced                      2.594078          comedy
# 229587  25843074     enhanced                      2.361370          comedy
# 281340  24799085         base                           NaN          comedy
# 87198   21308040         base                           NaN          comedy
# 598241  20166335         base                           NaN          comedy
#
#                        intended_use  weekly_consumption_hour  \
# 162502  access to exclusive content                      NaN
# 380374  access to exclusive content                22.951579
# 496617                  replace OTT                36.001186
# 356799                  replace OTT                20.051667
# 681701                  replace OTT                22.951579
# 284782  access to exclusive content                20.051667
# 192823  access to exclusive content                20.051667
# 315863  access to exclusive content                34.551230
# 254782  access to exclusive content                25.851492
# 681969                  replace OTT                28.751405
# 99989        expand regional access                34.551230
# 290426  access to exclusive content                37.451142
# 277565               supplement OTT                28.751405
# 377093                  replace OTT                33.101274
# 546210  expand international access                30.201361
# 143042  access to exclusive content                      NaN
# 626743                  replace OTT                27.301448
# 673104                  replace OTT                27.301448
# 349365               supplement OTT                37.451142
# 598759  expand international access                30.201361
# 208223                  replace OTT                27.301448
# 384799  access to exclusive content                22.951579
# 386250                  replace OTT                21.501623
# 7506    expand international access                34.551230
# 389385  access to exclusive content                24.401536
# 338592  access to exclusive content                24.401536
# 343642  access to exclusive content                      NaN
# 290800  access to exclusive content                21.501623
# 179332                  replace OTT                30.201361
# 216541  access to exclusive content                      NaN
# ...                             ...                      ...
# 582992  access to exclusive content                28.751405
# 117388  access to exclusive content                      NaN
# 627527  access to exclusive content                30.201361
# 497110               supplement OTT                38.901099
# 99888   expand international access                25.851492
# 61453                   replace OTT                27.301448
# 632153                  replace OTT                25.851492
# 120555                  replace OTT                      NaN
# 1384         expand regional access                30.201361
# 354013                  replace OTT                33.101274
# 157820  access to exclusive content                25.851492
# 39499                   replace OTT                      NaN
# 110393  expand international access                -8.947459
# 33596                   replace OTT                      NaN
# 60056                supplement OTT                28.751405
# 553731                  replace OTT                21.501623
# 324200                  replace OTT                30.201361
# 254294  access to exclusive content                24.401536
# 243775  access to exclusive content                27.301448
# 136817                  replace OTT                      NaN
# 303902                  replace OTT                37.451142
# 378377  access to exclusive content                30.201361
# 230734                  replace OTT                      NaN
# 577745  access to exclusive content                28.751405
# 603751  access to exclusive content                24.401536
# 509326               supplement OTT                28.751405
# 229587                  replace OTT                27.301448
# 281340  access to exclusive content                31.651317
# 87198   access to exclusive content                      NaN
# 598241                  replace OTT                25.851492
#
#         num_ideal_streaming_services  retarget_TF   age male_TF  ...  \
# 162502                           NaN        False   NaN   False  ...
# 380374                           NaN        False  70.0   False  ...
# 496617                      1.951776        False  25.0    True  ...
# 356799                           NaN        False  30.0   False  ...
# 681701                      2.506384        False  28.0   False  ...
# 284782                           NaN        False  70.0   False  ...
# 192823                      1.860289        False  61.0   False  ...
# 315863                      1.870503        False  23.0   False  ...
# 254782                           NaN        False  73.0   False  ...
# 681969                      1.888272        False  71.0   False  ...
# 99989                            NaN        False  53.0    True  ...
# 290426                           NaN        False  24.0    True  ...
# 277565                      1.842940        False  57.0   False  ...
# 377093                      1.867353        False  54.0   False  ...
# 546210                           NaN        False  48.0   False  ...
# 143042                           NaN        False   NaN   False  ...
# 626743                           NaN        False  26.0   False  ...
# 673104                      1.822501        False  24.0   False  ...
# 349365                           NaN        False  50.0   False  ...
# 598759                           NaN        False  32.0   False  ...
# 208223                      1.849591         True  26.0   False  ...
# 384799                      2.330133        False  65.0   False  ...
# 386250                      1.929349        False  50.0   False  ...
# 7506                        1.927293        False  31.0   False  ...
# 389385                           NaN        False  21.0   False  ...
# 338592                      1.959115        False  37.0   False  ...
# 343642                           NaN        False   NaN   False  ...
# 290800                      2.623452        False  49.0   False  ...
# 179332                      1.860907        False  59.0   False  ...
# 216541                           NaN        False   NaN   False  ...
# ...                              ...          ...   ...     ...  ...
# 582992                      1.828606         True  55.0   False  ...
# 117388                           NaN        False   NaN   False  ...
# 627527                           NaN        False  36.0   False  ...
# 497110                      1.840610        False  45.0    True  ...
# 99888                       1.884191        False  19.0   False  ...
# 61453                       1.899624        False  55.0   False  ...
# 632153                      1.949272        False  36.0   False  ...
# 120555                           NaN        False   NaN   False  ...
# 1384                        1.958703        False  34.0   False  ...
# 354013                      1.867354        False  57.0   False  ...
# 157820                      1.981060        False  46.0   False  ...
# 39499                            NaN        False   NaN   False  ...
# 110393                           NaN        False  43.0   False  ...
# 33596                            NaN        False   NaN   False  ...
# 60056                       1.867903        False  55.0   False  ...
# 553731                      1.919544        False  45.0   False  ...
# 324200                      1.854666        False  52.0   False  ...
# 254294                           NaN        False  30.0   False  ...
# 243775                      2.317104        False  44.0   False  ...
# 136817                           NaN        False   NaN   False  ...
# 303902                           NaN        False  67.0    True  ...
# 378377                      1.968236        False  32.0   False  ...
# 230734                           NaN        False   NaN   False  ...
# 577745                           NaN        False  61.0   False  ...
# 603751                      1.881068        False  43.0   False  ...
# 509326                      1.905485        False  38.0   False  ...
# 229587                      1.835189         True  49.0   False  ...
# 281340                           NaN        False  45.0   False  ...
# 87198                            NaN        False   NaN   False  ...
# 598241                           NaN        False  55.0   False  ...
#
#        creation_until_cancel_days cancel_before_trial_end trial_end_date  \
# 162502                        NaN                    True     2020-02-08
# 380374                        0.0                   False     2020-03-16
# 496617                        1.0                   False     2019-12-22
# 356799                        0.0                   False     2020-02-11
# 681701                        9.0                   False     2019-10-20
# 284782                       71.0                    True     2020-03-18
# 192823                        NaN                    True     2020-03-05
# 315863                        NaN                    True     2020-03-20
# 254782                        1.0                   False     2020-03-09
# 681969                        4.0                   False     2020-02-05
# 99989                       158.0                    True     2019-07-26
# 290426                        6.0                   False     2019-12-16
# 277565                        8.0                   False     2019-10-13
# 377093                       13.0                   False     2019-08-31
# 546210                        2.0                   False     2019-07-21
# 143042                        NaN                    True     2020-03-24
# 626743                        0.0                   False     2019-10-17
# 673104                       12.0                   False     2019-10-31
# 349365                        1.0                   False     2020-01-29
# 598759                        0.0                   False     2019-07-21
# 208223                      153.0                    True     2019-11-26
# 384799                        8.0                   False     2020-03-18
# 386250                       10.0                   False     2020-03-20
# 7506                         56.0                    True     2019-07-28
# 389385                        0.0                   False     2020-03-24
# 338592                       13.0                   False     2020-03-28
# 343642                        NaN                    True     2020-04-02
# 290800                       23.0                    True     2020-03-23
# 179332                        NaN                    True     2020-01-04
# 216541                        NaN                    True     2020-02-23
# ...                           ...                     ...            ...
# 582992                        2.0                   False     2019-10-22
# 117388                        NaN                    True     2019-11-24
# 627527                        4.0                   False     2019-12-13
# 497110                        1.0                   False     2020-03-08
# 99888                         NaN                    True     2019-08-05
# 61453                         NaN                    True     2020-01-19
# 632153                        5.0                   False     2020-02-06
# 120555                        NaN                    True     2019-12-05
# 1384                          NaN                    True     2019-08-09
# 354013                        8.0                   False     2019-10-08
# 157820                        NaN                    True     2020-03-17
# 39499                         NaN                    True     2019-10-04
# 110393                       14.0                    True     2019-07-27
# 33596                        16.0                    True     2019-09-15
# 60056                         NaN                    True     2019-12-05
# 553731                       14.0                   False     2019-08-25
# 324200                        3.0                   False     2019-09-07
# 254294                       33.0                    True     2020-02-18
# 243775                        NaN                    True     2020-03-12
# 136817                        NaN                    True     2019-09-29
# 303902                        3.0                   False     2019-12-01
# 378377                        1.0                   False     2019-10-15
# 230734                        NaN                    True     2020-01-29
# 577745                        0.0                   False     2020-03-21
# 603751                       11.0                   False     2020-01-16
# 509326                        8.0                   False     2019-12-02
# 229587                        NaN                    True     2019-12-21
# 281340                       31.0                    True     2020-01-05
# 87198                         NaN                    True     2020-02-01
# 598241                        4.0                   False     2019-12-11
#
#        initial_credit_card_declined  revenue_net join_fee  language  paid_TF  \
# 162502                        False          NaN      NaN        ar     True
# 380374                        False       0.0000   0.3303        ar    False
# 496617                        False       0.0000   0.1101        ar    False
# 356799                        False       0.0000   0.0367        ar    False
# 681701                        False       0.0000   0.0367        ar    False
# 284782                        False       0.0000   0.3303        ar     True
# 192823                        False       4.5875   0.3303        ar     True
# 315863                        False       3.4498   0.0000        ar     True
# 254782                        False       0.0000   0.6606        ar    False
# 681969                        False       0.0000   0.3303        ar    False
# 99989                         False       9.2117   0.0367        ar     True
# 290426                        False       0.0000   0.3303        ar    False
# 277565                        False       0.0000   0.0367        ar    False
# 377093                        False       0.0000   0.0367        ar    False
# 546210                        False       0.0000   0.0367        ar    False
# 143042                        False          NaN      NaN        ar     True
# 626743                        False       0.0000   0.0367        ar    False
# 673104                        False       0.0000   0.0367        ar    False
# 349365                        False       0.0000   0.0367        ar    False
# 598759                        False       0.0000   0.0000        ar    False
# 208223                        False       3.2296   0.0367        ar     True
# 384799                        False       0.0000   0.3303        ar    False
# 386250                        False       0.0000   0.3303        ar    False
# 7506                          False       1.6148   0.0367        ar     True
# 389385                        False       0.0000   0.3303        ar    False
# 338592                        False       0.0000   0.6606        ar    False
# 343642                        False          NaN      NaN        ar     True
# 290800                        False       0.0000   0.1101        ar     True
# 179332                        False       4.5875   0.3303        ar     True
# 216541                        False          NaN      NaN        ar     True
# ...                             ...          ...      ...       ...      ...
# 582992                        False       0.0000   0.0367        ar    False
# 117388                        False          NaN      NaN        ar     True
# 627527                        False       0.0000   0.0367        ar    False
# 497110                        False       0.0000   0.0000        ar    False
# 99888                         False       7.4134   0.0000        ar     True
# 61453                         False       5.0279   0.0367        ar     True
# 632153                        False       0.0000   0.1101        ar    False
# 120555                        False          NaN      NaN        ar     True
# 1384                          False       4.5875   0.0367        ar     True
# 354013                        False       0.0000   0.0367        ar    False
# 157820                        False       4.5875   0.3303        ar     True
# 39499                         False          NaN      NaN        ar     True
# 110393                        False       0.0000   0.0367        ar     True
# 33596                         False          NaN      NaN        ar     True
# 60056                         False       9.7622   0.0000        ar     True
# 553731                        False       0.0000   0.0367        ar    False
# 324200                        False       0.0000   0.0367        ar    False
# 254294                        False       0.0000   0.0367        ar     True
# 243775                        False      -0.6973   0.0000        ar     True
# 136817                        False          NaN      NaN        ar     True
# 303902                        False       0.0000   0.0367        ar    False
# 378377                        False       0.0000   0.0000        ar    False
# 230734                        False          NaN      NaN        ar     True
# 577745                        False       0.0000   0.3303        ar    False
# 603751                        False       0.0000   0.0000        ar    False
# 509326                        False       0.0000   0.3303        ar    False
# 229587                        False       4.5875   0.3303        ar     True
# 281340                         True       0.0000   0.0367        ar    False
# 87198                         False          NaN      NaN        ar     True
# 598241                        False       0.0000   0.0367        ar    False
#
#        refund_after_trial_TF      payment_type
# 162502                 False  Standard Charter
# 380374                 False               NaN
# 496617                 False               NaN
# 356799                 False               NaN
# 681701                 False               NaN
# 284782                  True           RAKBANK
# 192823                 False  Standard Charter
# 315863                 False           RAKBANK
# 254782                 False               NaN
# 681969                 False               NaN
# 99989                  False  Standard Charter
# 290426                 False               NaN
# 277565                 False               NaN
# 377093                 False               NaN
# 546210                 False               NaN
# 143042                 False            Paypal
# 626743                 False               NaN
# 673104                 False               NaN
# 349365                 False               NaN
# 598759                 False               NaN
# 208223                 False           RAKBANK
# 384799                 False               NaN
# 386250                 False               NaN
# 7506                    True  Standard Charter
# 389385                 False               NaN
# 338592                 False               NaN
# 343642                 False  Standard Charter
# 290800                  True           RAKBANK
# 179332                 False           RAKBANK
# 216541                 False  Standard Charter
# ...                      ...               ...
# 582992                 False               NaN
# 117388                 False            Paypal
# 627527                 False               NaN
# 497110                 False               NaN
# 99888                  False           RAKBANK
# 61453                  False  Standard Charter
# 632153                 False               NaN
# 120555                 False  Standard Charter
# 1384                   False  Standard Charter
# 354013                 False               NaN
# 157820                 False           RAKBANK
# 39499                  False            Paypal
# 110393                  True            Paypal
# 33596                   True            Paypal
# 60056                  False            Paypal
# 553731                 False               NaN
# 324200                 False               NaN
# 254294                  True            Paypal
# 243775                 False  Standard Charter
# 136817                 False  Standard Charter
# 303902                 False               NaN
# 378377                 False               NaN
# 230734                 False           RAKBANK
# 577745                 False               NaN
# 603751                 False               NaN
# 509326                 False               NaN
# 229587                 False            Paypal
# 281340                 False               NaN
# 87198                  False            Paypal
# 598241                 False               NaN
#
# [227628 rows x 29 columns]

# %%
len(customer['subid'].unique())
# Out:
# 227628

# %% [markdown]
# #### 1.2 Service dataset

# %%
service = pd.read_pickle(r'customer_service_reps')

service
# Out:
#          customer_service_rep_id     subid  current_sub_TF  \
# 4                       36189811  25108574           False
# 5                       36189811  25108574           False
# 6                       36189811  25108574           False
# 7                       36189811  25108574           False
# 8                       31174901  25914865            True
# 9                       31174901  25914865            True
# 10                      32408758  28778936            True
# 11                      32408758  28778936            True
# 12                      39370969  21481314            True
# 13                      39370969  21481314            True
# 14                      38637729  24230000            True
# 15                      38637729  24230000            True
# 16                      37537571  22111363            True
# 17                      37537571  22111363            True
# 18                      31649550  26606371            True
# 19                      31649550  26606371            True
# 20                      32585559  25421493            True
# 21                      32585559  25421493            True
# 22                      39294567  24120196            True
# 23                      39294567  24120196            True
# 24                      37336404  29409169            True
# 25                      37336404  29409169            True
# 26                      37061900  20154887            True
# 27                      37061900  20154887            True
# 28                      30552635  22657468            True
# 29                      30552635  22657468            True
# 30                      38604226  24857015            True
# 31                      38604226  24857015            True
# 32                      38500872  23157022            True
# 33                      38500872  23157022            True
# ...                          ...       ...             ...
# 2248384                 39575996  21199804           False
# 2248385                 38865556  27585257           False
# 2248386                 38865556  27585257           False
# 2248387                 34437033  22486506           False
# 2248388                 30967722  24792193            True
# 2248389                 30967722  24792193            True
# 2248390                 30967722  24792193            True
# 2248391                 30967722  24792193            True
# 2248392                 34428685  22348406           False
# 2248393                 30177012  28661481           False
# 2248394                 30947283  26986758           False
# 2248395                 39561825  22320767           False
# 2248396                 39561825  22320767           False
# 2248397                 38865556  23575229           False
# 2248398                 38960743  27633581           False
# 2248399                 31803812  21965147           False
# 2248400                 33218156  21781165            True
# 2248401                 33218156  21781165            True
# 2248402                 34478389  27625059           False
# 2248403                 38647874  27845350           False
# 2248404                 38647874  27845350           False
# 2248405                 38647874  27845350           False
# 2248406                 30859916  26845271           False
# 2248407                 30859916  26845271           False
# 2248408                 30859916  26845271           False
# 2248409                 30859916  26845271           False
# 2248410                 30859916  26845271           False
# 2248411                 30859916  26845271           False
# 2248412                 30859916  26845271           False
# 2248413                 30859916  26845271           False
#
#                 cancel_date account_creation_date  num_trial_days  \
# 4                       NaT   2019-11-26 03:30:29               7
# 5                       NaT   2019-11-26 03:30:29               7
# 6                       NaT   2019-11-26 03:30:29               7
# 7                       NaT   2019-11-26 03:30:29               7
# 8                       NaT   2020-03-19 01:20:25              14
# 9                       NaT   2020-03-19 01:20:25              14
# 10                      NaT   2020-03-27 23:46:37               0
# 11                      NaT   2020-03-27 23:46:37               0
# 12                      NaT   2020-03-27 23:09:18               0
# 13                      NaT   2020-03-27 23:09:18               0
# 14                      NaT   2020-03-27 22:59:09               0
# 15                      NaT   2020-03-27 22:59:09               0
# 16                      NaT   2020-03-27 22:38:36               0
# 17                      NaT   2020-03-27 22:38:36               0
# 18                      NaT   2020-03-27 22:06:38               0
# 19                      NaT   2020-03-27 22:06:38               0
# 20                      NaT   2020-03-27 20:53:17               0
# 21                      NaT   2020-03-27 20:53:17               0
# 22                      NaT   2020-03-27 23:14:23               0
# 23                      NaT   2020-03-27 23:14:23               0
# 24                      NaT   2020-03-27 21:08:55               0
# 25                      NaT   2020-03-27 21:08:55               0
# 26                      NaT   2020-03-27 22:59:12               0
# 27                      NaT   2020-03-27 22:59:12               0
# 28                      NaT   2020-03-27 21:46:25               0
# 29                      NaT   2020-03-27 21:46:25               0
# 30                      NaT   2020-03-27 22:36:34               0
# 31                      NaT   2020-03-27 22:36:34               0
# 32                      NaT   2020-03-27 21:22:08               0
# 33                      NaT   2020-03-27 21:22:08               0
# ...                     ...                   ...             ...
# 2248384 2019-06-30 16:28:31   2019-06-30 00:01:28              14
# 2248385                 NaT   2019-06-30 00:01:25              14
# 2248386                 NaT   2019-06-30 00:01:25              14
# 2248387 2019-06-30 16:33:46   2019-06-30 00:01:25              14
# 2248388                 NaT   2019-06-30 00:01:11              14
# 2248389                 NaT   2019-06-30 00:01:11              14
# 2248390                 NaT   2019-06-30 00:01:11              14
# 2248391                 NaT   2019-06-30 00:01:11              14
# 2248392 2019-07-07 14:01:09   2019-06-30 00:01:08              14
# 2248393 2019-07-09 15:32:06   2019-06-30 00:00:59              14
# 2248394 2019-07-12 23:23:24   2019-06-30 00:00:51              14
# 2248395 2019-11-27 09:30:04   2019-06-30 00:00:34              14
# 2248396 2019-11-27 09:30:04   2019-06-30 00:00:34              14
# 2248397 2019-06-30 00:51:54   2019-06-30 00:00:19              14
# 2248398 2019-07-06 13:25:38   2019-06-30 00:00:14              14
# 2248399 2019-07-04 15:37:24   2019-06-30 00:00:13              14
# 2248400                 NaT   2019-06-30 00:00:06              14
# 2248401                 NaT   2019-06-30 00:00:06              14
# 2248402 2019-07-01 10:27:01   2019-06-30 00:00:06              14
# 2248403                 NaT   2019-06-30 00:00:04              14
# 2248404                 NaT   2019-06-30 00:00:04              14
# 2248405                 NaT   2019-06-30 00:00:04              14
# 2248406                 NaT   2019-06-30 06:24:24               0
# 2248407                 NaT   2019-06-30 06:24:24               0
# 2248408                 NaT   2019-06-30 06:24:24               0
# 2248409                 NaT   2019-06-30 06:24:24               0
# 2248410                 NaT   2019-06-30 06:24:24               0
# 2248411                 NaT   2019-06-30 06:24:24               0
# 2248412                 NaT   2019-06-30 06:24:24               0
# 2248413                 NaT   2019-06-30 06:24:24               0
#
#          trial_completed_TF billing_channel  revenue_net_1month  \
# 4                      True          itunes              1.1377
# 5                      True          itunes              1.1377
# 6                      True          itunes              1.1377
# 7                      True          itunes              1.1377
# 8                      True          itunes              1.1377
# 9                      True          itunes              1.1377
# 10                     True          google              1.1377
# 11                     True          google              1.1377
# 12                     True          google              1.1377
# 13                     True          google              1.1377
# 14                     True          google              1.1377
# 15                     True          google              1.1377
# 16                     True          google              1.1377
# 17                     True          google              1.1377
# 18                     True          google              1.1377
# 19                     True          google              1.1377
# 20                     True          google              1.1377
# 21                     True          google              1.1377
# 22                     True          google              1.1377
# 23                     True          google              1.1377
# 24                     True          google              1.1377
# 25                     True          google              1.1377
# 26                     True          google              1.1377
# 27                     True          google              1.1377
# 28                     True          google              1.1377
# 29                     True          google              1.1377
# 30                     True          google              1.1377
# 31                     True          google              1.1377
# 32                     True          google              0.7707
# 33                     True          google              0.7707
# ...                     ...             ...                 ...
# 2248384               False             OTT              0.0000
# 2248385                True             OTT              4.9178
# 2248386                True             OTT              4.9178
# 2248387               False             OTT              0.0000
# 2248388                True             OTT              4.7343
# 2248389                True             OTT              4.7343
# 2248390                True             OTT              4.7343
# 2248391                True             OTT              4.7343
# 2248392               False             OTT              0.0000
# 2248393               False             OTT              0.0000
# 2248394               False             OTT              0.0000
# 2248395                True             OTT              4.5875
# 2248396                True             OTT              4.5875
# 2248397               False             OTT              0.0000
# 2248398               False             OTT              0.0000
# 2248399               False             OTT              0.0000
# 2248400                True             OTT              3.8902
# 2248401                True             OTT              3.8902
# 2248402               False             OTT              0.0000
# 2248403                True             OTT              3.5232
# 2248404                True             OTT              3.5232
# 2248405                True             OTT              3.5232
# 2248406                True          google              0.6239
# 2248407                True          google              0.6239
# 2248408                True          google              0.6239
# 2248409                True          google              0.6239
# 2248410                True          google              0.6239
# 2248411                True          google              0.6239
# 2248412                True          google              0.6239
# 2248413                True          google              0.6239
#
#          payment_period        last_payment        next_payment  renew
# 4                     0 2019-11-26 03:30:29 2019-11-26 03:30:29    NaN
# 5                     1 2019-11-26 03:30:29 2019-12-27 03:30:29    NaN
# 6                     2 2019-12-27 03:30:29 2020-01-26 03:30:29    NaN
# 7                     3 2020-01-26 03:30:29                 NaT    NaN
# 8                     0 2020-03-19 01:20:25 2020-04-02 01:20:25    NaN
# 9                     1 2020-04-02 01:20:25                 NaT    NaN
# 10                    0 2020-03-27 23:46:37 2020-03-28 06:47:31    NaN
# 11                    1 2020-03-28 06:47:31                 NaT    NaN
# 12                    0 2020-03-27 23:09:18 2020-03-28 05:09:22    NaN
# 13                    1 2020-03-28 05:09:22                 NaT    NaN
# 14                    0 2020-03-27 22:59:09 2020-03-28 04:59:17    NaN
# 15                    1 2020-03-28 04:59:17                 NaT    NaN
# 16                    0 2020-03-27 22:38:36 2020-03-28 04:38:39    NaN
# 17                    1 2020-03-28 04:38:39                 NaT    NaN
# 18                    0 2020-03-27 22:06:38 2020-03-28 04:06:42    NaN
# 19                    1 2020-03-28 04:06:42                 NaT    NaN
# 20                    0 2020-03-27 20:53:17 2020-03-28 03:53:23    NaN
# 21                    1 2020-03-28 03:53:23                 NaT    NaN
# 22                    0 2020-03-27 23:14:23 2020-03-28 03:14:28    NaN
# 23                    1 2020-03-28 03:14:28                 NaT    NaN
# 24                    0 2020-03-27 21:08:55 2020-03-28 03:09:03    NaN
# 25                    1 2020-03-28 03:09:03                 NaT    NaN
# 26                    0 2020-03-27 22:59:12 2020-03-28 02:59:18    NaN
# 27                    1 2020-03-28 02:59:18                 NaT    NaN
# 28                    0 2020-03-27 21:46:25 2020-03-28 02:46:44    NaN
# 29                    1 2020-03-28 02:46:44                 NaT    NaN
# 30                    0 2020-03-27 22:36:34 2020-03-28 02:36:38    NaN
# 31                    1 2020-03-28 02:36:38                 NaT    NaN
# 32                    0 2020-03-27 21:22:08 2020-03-28 02:22:11    NaN
# 33                    1 2020-03-28 02:22:11                 NaT    NaN
# ...                 ...                 ...                 ...    ...
# 2248384               0 2019-06-30 01:05:35                 NaT  False
# 2248385               0 2019-06-30 00:01:25 2019-07-14 14:33:09   True
# 2248386               1 2019-07-14 14:33:09                 NaT  False
# 2248387               0 2019-06-30 00:01:25                 NaT  False
# 2248388               0 2019-06-30 00:01:11 2019-07-14 18:43:52   True
# 2248389               1 2019-07-14 18:43:52 2019-11-11 19:27:12    NaN
# 2248390               2 2019-11-11 19:27:12 2020-03-13 19:27:38    NaN
# 2248391               3 2020-03-13 19:27:38                 NaT  False
# 2248392               0 2019-06-30 00:01:08                 NaT    NaN
# 2248393               0 2019-06-30 00:00:59                 NaT    NaN
# 2248394               0 2019-06-30 01:05:29                 NaT  False
# 2248395               0 2019-06-30 00:00:34 2019-07-14 10:43:57   True
# 2248396               1 2019-07-14 10:43:57                 NaT  False
# 2248397               0 2019-06-30 00:05:53                 NaT  False
# 2248398               0 2019-06-30 00:00:14                 NaT    NaN
# 2248399               0 2019-06-30 00:00:13                 NaT    NaN
# 2248400               0 2019-06-30 00:00:06 2019-07-14 11:05:50    NaN
# 2248401               1 2019-07-14 11:05:50                 NaT    NaN
# 2248402               0 2019-06-30 00:00:06                 NaT    NaN
# 2248403               0 2019-06-30 00:00:04 2019-07-14 11:07:06    NaN
# 2248404               1 2019-07-14 11:07:06 2019-09-11 11:07:12    NaN
# 2248405               2 2019-09-11 11:07:12                 NaT    NaN
# 2248406               0 2019-06-30 06:24:24 2019-06-29 20:24:28    NaN
# 2248407               1 2019-06-29 20:24:28 2019-07-30 20:23:27    NaN
# 2248408               2 2019-07-30 20:23:27 2019-08-27 20:23:27    NaN
# 2248409               3 2019-08-27 20:23:27 2019-09-24 20:23:29    NaN
# 2248410               4 2019-09-24 20:23:29 2019-10-25 20:23:28    NaN
# 2248411               5 2019-10-25 20:23:28 2019-11-24 20:23:29    NaN
# 2248412               6 2019-11-24 20:23:29 2019-12-25 20:23:27    NaN
# 2248413               7 2019-12-25 20:23:27                 NaT    NaN
#
# [2208643 rows x 13 columns]

# %%
for i in service.columns:
    print(i)
    print(sum(service[i].isnull()))
# Out:
# customer_service_rep_id
# 0
# subid
# 0
# current_sub_TF
# 0
# cancel_date
# 1354081
# account_creation_date
# 0
# num_trial_days
# 0
# trial_completed_TF
# 0
# billing_channel
# 0
# revenue_net_1month
# 0
# payment_period
# 0
# last_payment
# 0
# next_payment
# 1369360
# renew
# 1602396

# %%
service_by_individual = pd.pivot_table(service, index='subid', values=['current_sub_TF', 'num_trial_days', 
                            'trial_completed_TF', 'revenue_net_1month', 'payment_period'],
                                aggfunc = {'current_sub_TF':np.mean, 'num_trial_days':np.mean,
                                          'trial_completed_TF':np.mean, 'revenue_net_1month':np.mean,
                                          'payment_period':len})

service_by_individual.reset_index(drop=False, inplace=True)

service_by_individual.columns = ['subid', 'current_sub_TF', 'num_trial_days', 'total_payment_periods',
       'revenue_net_1month', 'trial_completed_TF']

service_by_individual
# Out:
#             subid  current_sub_TF  num_trial_days  total_payment_periods  \
# 0        20000002           False              14                      1
# 1        20000003           False              14                      1
# 2        20000007           False              14                      1
# 3        20000014           False              14                      1
# 4        20000031           False              14                      1
# 5        20000039           False              14                      3
# 6        20000040           False              14                      1
# 7        20000043            True              14                      3
# 8        20000045            True              14                      2
# 9        20000062           False              14                      1
# 10       20000067           False              14                      1
# 11       20000088           False              14                      1
# 12       20000089            True              14                      6
# 13       20000114           False              14                      1
# 14       20000116           False              14                      1
# 15       20000139           False              14                      2
# 16       20000153           False              14                      1
# 17       20000158           False              14                      1
# 18       20000189           False              14                      1
# 19       20000191           False              14                      1
# 20       20000201            True              14                      2
# 21       20000210           False              14                      1
# 22       20000211           False              14                      1
# 23       20000215           False              14                      2
# 24       20000216           False               7                      1
# 25       20000217           False              14                      1
# 26       20000227           False              14                      2
# 27       20000232           False              14                      2
# 28       20000240           False              14                      1
# 29       20000250           False              14                      1
# ...           ...             ...             ...                    ...
# 1369330  29999841           False               7                      1
# 1369331  29999842           False              14                      2
# 1369332  29999848           False              14                      3
# 1369333  29999859           False              14                      1
# 1369334  29999865           False              14                      1
# 1369335  29999869           False              14                      2
# 1369336  29999871           False              14                      3
# 1369337  29999875           False              14                      1
# 1369338  29999884           False              14                      1
# 1369339  29999887           False              14                      2
# 1369340  29999889           False              14                      3
# 1369341  29999890           False              14                      3
# 1369342  29999892           False              14                      1
# 1369343  29999898            True              14                      2
# 1369344  29999909           False              14                      1
# 1369345  29999916           False              14                      1
# 1369346  29999921           False              14                      1
# 1369347  29999922           False              14                      1
# 1369348  29999942           False              14                      1
# 1369349  29999944           False              14                      1
# 1369350  29999945            True              14                      2
# 1369351  29999948           False               0                      2
# 1369352  29999956           False              14                      2
# 1369353  29999965           False              14                      1
# 1369354  29999979           False              14                      2
# 1369355  29999986           False              14                      3
# 1369356  29999991           False              14                      2
# 1369357  29999993           False              14                      1
# 1369358  29999997           False              14                      1
# 1369359  29999998           False              14                      1
#
#          revenue_net_1month  trial_completed_TF
# 0                    0.0000               False
# 1                    0.0000               False
# 2                    0.0000               False
# 3                    0.0000               False
# 4                    0.0000               False
# 5                    4.5875                True
# 6                    0.0000               False
# 7                    1.1377                True
# 8                    3.8535                True
# 9                    0.0000               False
# 10                   0.0000               False
# 11                   0.0000               False
# 12                   3.5232                True
# 13                   0.0000               False
# 14                   0.0000               False
# 15                   4.5875                True
# 16                   0.0000               False
# 17                   0.0000               False
# 18                   0.0000                True
# 19                   0.0000                True
# 20                   5.3215                True
# 21                   0.0000               False
# 22                   0.0000               False
# 23                   4.1471                True
# 24                   0.0000                True
# 25                   0.0000               False
# 26                   1.1377                True
# 27                   4.5875                True
# 28                   0.0000               False
# 29                   0.0000               False
# ...                     ...                 ...
# 1369330              0.0000                True
# 1369331              4.5875                True
# 1369332              6.0555                True
# 1369333              0.0000                True
# 1369334              0.0000               False
# 1369335              0.0000                True
# 1369336              3.5232                True
# 1369337              0.0000               False
# 1369338              0.0000               False
# 1369339              5.3215                True
# 1369340              4.5875                True
# 1369341              2.3121                True
# 1369342              0.0000               False
# 1369343              4.9545                True
# 1369344              0.0000                True
# 1369345              0.0000               False
# 1369346              0.0000               False
# 1369347              0.0000                True
# 1369348              0.0000               False
# 1369349              0.0000               False
# 1369350              4.5875                True
# 1369351              1.1377                True
# 1369352              3.7434                True
# 1369353              0.0000               False
# 1369354              0.0000                True
# 1369355              2.4589                True
# 1369356              0.0000                True
# 1369357              0.0000               False
# 1369358              0.0000               False
# 1369359              0.0000               False
#
# [1369360 rows x 6 columns]

# %%
service_by_individual['current_sub_TF'].value_counts()
# Out:
# False    1040049
# True      329311
# Name: current_sub_TF, dtype: int64

# %%
service_by_individual['num_trial_days'].value_counts()
# Out:
# 14    1281127
# 7       64043
# 0       24190
# Name: num_trial_days, dtype: int64

# %%
service_by_individual['trial_completed_TF'].value_counts()
# Out:
# True     708433
# False    660927
# Name: trial_completed_TF, dtype: int64

# %% [markdown]
# #### 1.3 Engagement dataset

# %%
engag = pd.read_pickle(r'engagement')

engag
# Out:
#              subid       date  app_opens  cust_service_mssgs  \
# 1         22349235 2019-07-01        1.0                 1.0
# 2         22349235 2019-07-02        1.0                 0.0
# 3         22349235 2019-07-03        0.0                 1.0
# 50        20848497 2019-07-02        1.0                 0.0
# 51        22680106 2019-07-02        2.0                 1.0
# 53        22680106 2019-07-03        1.0                 0.0
# 55        20848497 2019-07-03        1.0                 1.0
# 56        22680106 2019-07-04        1.0                 0.0
# 58        20848497 2019-07-04        1.0                 1.0
# 59        20848497 2019-07-05        1.0                 0.0
# 60        22680106 2019-07-05        1.0                 0.0
# 62        22680106 2019-07-06        1.0                 0.0
# 64        20848497 2019-07-06        1.0                 0.0
# 65        22680106 2019-07-07        1.0                 0.0
# 67        20848497 2019-07-07        1.0                 0.0
# 68        22680106 2019-07-08        1.0                 0.0
# 70        20848497 2019-07-08        1.0                 1.0
# 71        22680106 2019-07-09        1.0                 0.0
# 73        20848497 2019-07-10        0.0                 0.0
# 74        22680106 2019-07-10        1.0                 0.0
# 76        22680106 2019-07-11        1.0                 0.0
# 78        22680106 2019-07-12        1.0                 0.0
# 81        22478137 2019-07-01        1.0                 1.0
# 82        22478137 2019-07-02        1.0                 0.0
# 83        22478137 2019-07-03        1.0                 0.0
# 84        22478137 2019-07-04        1.0                 0.0
# 85        22478137 2019-07-05        0.0                 1.0
# 91        21899628 2019-07-01        1.0                 0.0
# 92        21899628 2019-07-02        1.0                 1.0
# 93        21899628 2019-07-03        1.0                 1.0
# ...            ...        ...        ...                 ...
# 28832235  27373263 2020-04-18        2.0                 1.0
# 28832237  27373263 2020-04-22        0.0                 0.0
# 28832239  28409777 2020-03-29        7.0                 1.0
# 28832241  28409777 2020-03-30        4.0                 0.0
# 28832243  28409777 2020-03-31        4.0                 0.0
# 28832245  28409777 2020-04-01        4.0                 0.0
# 28832247  28409777 2020-04-02        3.0                 0.0
# 28832249  28409777 2020-04-03        2.0                 1.0
# 28832251  28409777 2020-04-04        2.0                 0.0
# 28832253  28409777 2020-04-05        0.0                 0.0
# 28832255  28409777 2020-04-06        3.0                 1.0
# 28832257  28409777 2020-04-07        3.0                 1.0
# 28832259  28409777 2020-04-08        2.0                 0.0
# 28832261  28409777 2020-04-09        1.0                 1.0
# 28832263  28409777 2020-04-10        3.0                 0.0
# 28832295  28409777 2020-04-11        4.0                 0.0
# 28832297  28409777 2020-04-12        4.0                 2.0
# 28832299  28409777 2020-04-13        4.0                 0.0
# 28832301  28409777 2020-04-14        2.0                 0.0
# 28832303  28409777 2020-04-15        4.0                 0.0
# 28832305  28409777 2020-04-16        4.0                 0.0
# 28832307  28409777 2020-04-17        2.0                 0.0
# 28832309  28409777 2020-04-18        4.0                 0.0
# 28832311  28409777 2020-04-19        7.0                 2.0
# 28832313  28409777 2020-04-20        4.0                 0.0
# 28832315  28409777 2020-04-21        2.0                 0.0
# 28832317  28409777 2020-04-22        2.0                 0.0
# 28832319  28409777 2020-04-23        0.0                 0.0
# 28832321  28409777 2020-04-24        1.0                 0.0
# 28832323  28409777 2020-04-25        1.0                 0.0
#
#           num_videos_completed  num_videos_more_than_30_seconds  \
# 1                          0.0                              6.0
# 2                          0.0                              5.0
# 3                          0.0                              0.0
# 50                         7.0                              7.0
# 51                         7.0                              7.0
# 53                         0.0                              6.0
# 55                         6.0                              6.0
# 56                         0.0                              5.0
# 58                         5.0                              5.0
# 59                         5.0                              5.0
# 60                         0.0                              5.0
# 62                         0.0                              5.0
# 64                         4.0                              5.0
# 65                         0.0                              4.0
# 67                         4.0                              4.0
# 68                         0.0                              5.0
# 70                         0.0                              5.0
# 71                         0.0                              5.0
# 73                         0.0                              4.0
# 74                         0.0                              4.0
# 76                         0.0                              4.0
# 78                         0.0                              4.0
# 81                         7.0                              7.0
# 82                         5.0                              6.0
# 83                         3.0                              5.0
# 84                         0.0                              5.0
# 85                         0.0                              0.0
# 91                         7.0                              7.0
# 92                         6.0                              6.0
# 93                         5.0                              5.0
# ...                        ...                              ...
# 28832235                   0.0                              4.0
# 28832237                   0.0                              4.0
# 28832239                   5.0                              5.0
# 28832241                   5.0                              5.0
# 28832243                   5.0                              5.0
# 28832245                   5.0                              5.0
# 28832247                   5.0                              5.0
# 28832249                   5.0                              5.0
# 28832251                   4.0                              4.0
# 28832253                   4.0                              4.0
# 28832255                   4.0                              4.0
# 28832257                   4.0                              4.0
# 28832259                   4.0                              4.0
# 28832261                   4.0                              4.0
# 28832263                   3.0                              4.0
# 28832295                   5.0                              5.0
# 28832297                   4.0                              4.0
# 28832299                   4.0                              4.0
# 28832301                   4.0                              4.0
# 28832303                   4.0                              4.0
# 28832305                   0.0                              4.0
# 28832307                   5.0                              5.0
# 28832309                   4.0                              4.0
# 28832311                   4.0                              4.0
# 28832313                   3.0                              4.0
# 28832315                   4.0                              4.0
# 28832317                   4.0                              4.0
# 28832319                   4.0                              4.0
# 28832321                   3.0                              4.0
# 28832323                   0.0                              4.0
#
#           num_videos_rated  num_series_started  payment_period
# 1                      0.0                 0.0             0.0
# 2                      0.0                 0.0             0.0
# 3                      0.0                 0.0             0.0
# 50                     0.0                 0.0             0.0
# 51                     0.0                 1.0             0.0
# 53                     0.0                 1.0             0.0
# 55                     0.0                 1.0             0.0
# 56                     0.0                 1.0             0.0
# 58                     0.0                 1.0             0.0
# 59                     0.0                 1.0             0.0
# 60                     0.0                 1.0             0.0
# 62                     0.0                 0.0             0.0
# 64                     0.0                 1.0             0.0
# 65                     0.0                 0.0             0.0
# 67                     0.0                 1.0             0.0
# 68                     0.0                 1.0             0.0
# 70                     0.0                 0.0             0.0
# 71                     0.0                 0.0             0.0
# 73                     0.0                 0.0             0.0
# 74                     0.0                 1.0             0.0
# 76                     0.0                 1.0             0.0
# 78                     0.0                 1.0             0.0
# 81                     0.0                 0.0             0.0
# 82                     0.0                 1.0             0.0
# 83                     0.0                 1.0             0.0
# 84                     0.0                 0.0             0.0
# 85                     0.0                 0.0             0.0
# 91                     0.0                 0.0             0.0
# 92                     0.0                 1.0             0.0
# 93                     0.0                 1.0             0.0
# ...                    ...                 ...             ...
# 28832235               0.0                 0.0             1.0
# 28832237               0.0                 0.0             1.0
# 28832239               0.0                 1.0             1.0
# 28832241               0.0                 1.0             1.0
# 28832243               0.0                 1.0             1.0
# 28832245               0.0                 1.0             1.0
# 28832247               0.0                 0.0             1.0
# 28832249               0.0                 1.0             1.0
# 28832251               0.0                 1.0             1.0
# 28832253               0.0                 1.0             1.0
# 28832255               0.0                 1.0             1.0
# 28832257               0.0                 0.0             1.0
# 28832259               0.0                 0.0             1.0
# 28832261               0.0                 1.0             1.0
# 28832263               0.0                 1.0             1.0
# 28832295               0.0                 1.0             1.0
# 28832297               0.0                 1.0             1.0
# 28832299               0.0                 1.0             1.0
# 28832301               0.0                 1.0             1.0
# 28832303               0.0                 1.0             1.0
# 28832305               0.0                 0.0             1.0
# 28832307               0.0                 1.0             1.0
# 28832309               0.0                 1.0             1.0
# 28832311               0.0                 1.0             1.0
# 28832313               1.0                 1.0             1.0
# 28832315               0.0                 1.0             1.0
# 28832317               0.0                 1.0             1.0
# 28832319               0.0                 1.0             1.0
# 28832321               1.0                 1.0             1.0
# 28832323               0.0                 1.0             1.0
#
# [2585724 rows x 9 columns]

# %%
len(engag['subid'].unique())
# Out:
# 135019

# %%
feature_list = ['app_opens', 'cust_service_mssgs',
       'num_videos_completed', 'num_videos_more_than_30_seconds',
       'num_videos_rated', 'num_series_started']

engag_by_individual = pd.pivot_table(engag, values=feature_list, index='subid', aggfunc=np.mean)
engag_by_individual.reset_index(drop=False, inplace=True)
engag_by_individual
# Out:
#            subid  app_opens  cust_service_mssgs  num_series_started  \
# 0       20000062   1.000000            0.750000            0.250000
# 1       20000405   1.250000            1.000000            0.250000
# 2       20000604   0.933333            0.333333            0.066667
# 3       20000685   1.210526            0.263158            0.210526
# 4       20000741   0.500000            0.500000            0.000000
# 5       20000796   4.826087            0.826087            0.913043
# 6       20000809   1.750000            0.500000            0.250000
# 7       20000863   1.125000            0.625000            0.000000
# 8       20000963   0.666667            0.250000            0.333333
# 9       20000992   1.000000            0.500000            0.750000
# 10      20001112   0.666667            0.083333            0.722222
# 11      20001132   0.978261            0.369565            0.391304
# 12      20001164   6.222222            0.444444            0.888889
# 13      20001169   2.000000            1.666667            0.333333
# 14      20001209   0.750000            0.250000            0.000000
# 15      20001231   1.125000            0.125000            0.000000
# 16      20001350   1.250000            0.500000            0.000000
# 17      20001429   1.000000            1.400000            1.000000
# 18      20001679   1.000000            0.600000            0.000000
# 19      20001699   1.000000            0.400000            0.000000
# 20      20001713   1.000000            0.200000            0.000000
# 21      20001788   1.166667            0.666667            0.500000
# 22      20001800   3.553846            0.184615            0.646154
# 23      20001820   3.600000            0.333333            0.266667
# 24      20001949   3.909091            0.636364            0.757576
# 25      20001981   1.000000            0.333333            0.000000
# 26      20001988   1.625000            0.500000            0.250000
# 27      20002159   2.136364            0.250000            0.863636
# 28      20002216   5.326087            0.260870            0.782609
# 29      20002248   1.000000            0.230769            0.000000
# ...          ...        ...                 ...                 ...
# 134989  29997662   1.000000            1.000000            0.600000
# 134990  29997728   0.710526            0.184211            0.052632
# 134991  29997791  14.195652            0.521739            1.000000
# 134992  29997838   2.000000            0.000000            0.000000
# 134993  29997865   1.000000            2.000000            0.333333
# 134994  29997978   1.105263            0.092105            0.986842
# 134995  29998133   1.468750            0.125000            0.406250
# 134996  29998158   0.500000            1.000000            0.000000
# 134997  29998186   1.250000            0.750000            0.250000
# 134998  29998441   0.750000            0.500000            0.000000
# 134999  29998442   1.000000            0.500000            0.500000
# 135000  29998599   3.526316            0.236842            0.736842
# 135001  29998629   1.500000            1.500000            0.000000
# 135002  29998711   1.000000            1.500000            1.000000
# 135003  29998725   3.000000            2.000000            0.000000
# 135004  29998731   2.578947            0.276316            0.921053
# 135005  29998796   4.800000            0.600000            0.600000
# 135006  29998835   3.804348            0.086957            0.956522
# 135007  29999005   1.723684            0.131579            0.986842
# 135008  29999052   0.666667            0.333333            0.000000
# 135009  29999196   0.769231            1.153846            1.000000
# 135010  29999206   6.086957            0.326087            0.978261
# 135011  29999335   1.000000            0.416667            0.666667
# 135012  29999524   1.000000            0.500000            0.000000
# 135013  29999590   2.500000            0.166667            0.750000
# 135014  29999740   1.071429            0.214286            0.000000
# 135015  29999820   1.200000            0.600000            0.700000
# 135016  29999822   1.000000            0.800000            0.200000
# 135017  29999889   3.223684            0.592105            0.894737
# 135018  29999945   0.972973            0.054054            0.729730
#
#         num_videos_completed  num_videos_more_than_30_seconds  \
# 0                   1.500000                         5.750000
# 1                   3.250000                         4.250000
# 2                   0.533333                         4.533333
# 3                   0.368421                         4.342105
# 4                   1.000000                         3.500000
# 5                   4.217391                         4.413043
# 6                   0.500000                         2.750000
# 7                   0.750000                         4.250000
# 8                   2.666667                         3.500000
# 9                   2.750000                         5.250000
# 10                  1.250000                         4.138889
# 11                  3.130435                         4.478261
# 12                  4.444444                         5.666667
# 13                  4.000000                         6.000000
# 14                  0.500000                         5.500000
# 15                  0.500000                         1.625000
# 16                  0.500000                         4.000000
# 17                  4.933333                         4.933333
# 18                  1.600000                         3.400000
# 19                  0.000000                         1.800000
# 20                  0.000000                         5.400000
# 21                  2.500000                         5.333333
# 22                  1.769231                         4.507692
# 23                  0.533333                         4.133333
# 24                  3.757576                         4.484848
# 25                  2.333333                         6.000000
# 26                  2.250000                         4.625000
# 27                  3.045455                         4.363636
# 28                  2.608696                         4.413043
# 29                  0.000000                         1.538462
# ...                      ...                              ...
# 134989              4.000000                         5.600000
# 134990              0.236842                         4.394737
# 134991              4.000000                         4.478261
# 134992              4.000000                         7.000000
# 134993              3.666667                         6.000000
# 134994              4.092105                         4.289474
# 134995              1.281250                         3.828125
# 134996              3.500000                         3.500000
# 134997              1.000000                         5.750000
# 134998              0.000000                         2.000000
# 134999              6.500000                         6.500000
# 135000              3.986842                         4.289474
# 135001              1.000000                         5.500000
# 135002              5.500000                         5.500000
# 135003              0.000000                         6.000000
# 135004              2.815789                         4.289474
# 135005              4.600000                         7.800000
# 135006              4.434783                         4.478261
# 135007              4.223684                         5.197368
# 135008              0.333333                         5.500000
# 135009              4.461538                         4.692308
# 135010              4.456522                         4.478261
# 135011              4.500000                         5.166667
# 135012              0.500000                         3.000000
# 135013              1.750000                         4.277778
# 135014              0.785714                         2.214286
# 135015              2.200000                         5.000000
# 135016              0.400000                         5.000000
# 135017              4.289474                         4.289474
# 135018              3.540541                         4.486486
#
#         num_videos_rated
# 0               0.000000
# 1               0.000000
# 2               0.000000
# 3               0.000000
# 4               0.000000
# 5               0.065217
# 6               0.000000
# 7               0.000000
# 8               0.000000
# 9               0.000000
# 10              0.000000
# 11              0.130435
# 12              0.000000
# 13              0.000000
# 14              0.000000
# 15              0.000000
# 16              0.000000
# 17              0.000000
# 18              0.000000
# 19              0.000000
# 20              0.000000
# 21              0.000000
# 22              0.061538
# 23              0.000000
# 24              0.060606
# 25              0.000000
# 26              0.000000
# 27              0.000000
# 28              0.065217
# 29              0.000000
# ...                  ...
# 134989          0.000000
# 134990          0.000000
# 134991          0.195652
# 134992          0.000000
# 134993          0.000000
# 134994          0.013158
# 134995          0.000000
# 134996          0.000000
# 134997          0.000000
# 134998          0.000000
# 134999          0.000000
# 135000          0.000000
# 135001          0.000000
# 135002          0.000000
# 135003          0.000000
# 135004          0.184211
# 135005          0.000000
# 135006          0.000000
# 135007          0.000000
# 135008          0.000000
# 135009          0.000000
# 135010          0.021739
# 135011          0.000000
# 135012          0.000000
# 135013          0.000000
# 135014          0.000000
# 135015          0.000000
# 135016          0.000000
# 135017          0.526316
# 135018          0.000000
#
# [135019 rows x 7 columns]

# %%
engag_at_period_0 = engag[engag['payment_period']==0]

print(engag_at_period_0.shape)

len(engag_at_period_0['subid'].unique())
# Out:
# (1172085, 9)
# 134992

# %%
engag_period_0_by_individual = pd.pivot_table(engag_at_period_0, values=feature_list, index='subid', aggfunc=np.mean)
engag_period_0_by_individual.reset_index(drop=False, inplace=True)
engag_period_0_by_individual
# Out:
#            subid  app_opens  cust_service_mssgs  num_series_started  \
# 0       20000062   1.000000            0.750000            0.250000
# 1       20000405   1.250000            1.000000            0.250000
# 2       20000604   1.000000            0.307692            0.076923
# 3       20000685   1.307692            0.307692            0.538462
# 4       20000741   0.500000            0.500000            0.000000
# 5       20000796   5.200000            1.866667            0.933333
# 6       20000809   1.000000            1.000000            1.000000
# 7       20000863   1.125000            0.625000            0.000000
# 8       20000963   0.666667            0.250000            0.333333
# 9       20000992   1.000000            0.500000            0.750000
# 10      20001112   0.866667            0.133333            0.866667
# 11      20001132   1.000000            0.333333            0.666667
# 12      20001164   6.222222            0.444444            0.888889
# 13      20001169   2.000000            1.666667            0.333333
# 14      20001209   0.750000            0.250000            0.000000
# 15      20001231   1.125000            0.125000            0.000000
# 16      20001350   1.250000            0.500000            0.000000
# 17      20001429   1.000000            1.400000            1.000000
# 18      20001679   1.000000            0.600000            0.000000
# 19      20001699   1.000000            0.400000            0.000000
# 20      20001713   1.000000            0.200000            0.000000
# 21      20001788   1.166667            0.666667            0.500000
# 22      20001800  10.066667            0.266667            1.000000
# 23      20001820   3.600000            0.333333            0.266667
# 24      20001949   5.333333            0.933333            0.933333
# 25      20001981   1.000000            0.333333            0.000000
# 26      20001988   1.625000            0.500000            0.250000
# 27      20002159   2.200000            0.333333            0.866667
# 28      20002216   6.866667            0.466667            1.000000
# 29      20002248   1.000000            0.230769            0.000000
# ...          ...        ...                 ...                 ...
# 134962  29997662   1.000000            1.000000            0.600000
# 134963  29997728   0.733333            0.333333            0.133333
# 134964  29997791  20.933333            0.533333            1.000000
# 134965  29997838   2.000000            0.000000            0.000000
# 134966  29997865   1.000000            2.000000            0.333333
# 134967  29997978   1.000000            0.266667            0.933333
# 134968  29998133   0.916667            0.000000            0.333333
# 134969  29998158   0.500000            1.000000            0.000000
# 134970  29998186   1.250000            0.750000            0.250000
# 134971  29998441   0.500000            1.000000            0.000000
# 134972  29998442   1.000000            0.500000            0.500000
# 134973  29998599   4.066667            0.466667            0.866667
# 134974  29998629   1.000000            0.000000            0.000000
# 134975  29998711   1.000000            1.500000            1.000000
# 134976  29998725   3.000000            2.000000            0.000000
# 134977  29998731   0.800000            0.333333            0.800000
# 134978  29998796   4.800000            0.600000            0.600000
# 134979  29998835   3.133333            0.266667            0.933333
# 134980  29999005   1.866667            0.400000            0.933333
# 134981  29999052   0.666667            0.333333            0.000000
# 134982  29999196   0.769231            1.153846            1.000000
# 134983  29999206   6.933333            0.533333            0.933333
# 134984  29999335   1.000000            0.416667            0.666667
# 134985  29999524   1.000000            0.500000            0.000000
# 134986  29999590   2.857143            0.285714            0.928571
# 134987  29999740   1.071429            0.214286            0.000000
# 134988  29999820   1.200000            0.600000            0.700000
# 134989  29999822   1.000000            0.800000            0.200000
# 134990  29999889   2.933333            0.933333            1.000000
# 134991  29999945   0.866667            0.133333            0.733333
#
#         num_videos_completed  num_videos_more_than_30_seconds  \
# 0                   1.500000                         5.750000
# 1                   3.250000                         4.250000
# 2                   0.615385                         4.923077
# 3                   0.846154                         4.846154
# 4                   1.000000                         3.500000
# 5                   4.466667                         4.800000
# 6                   2.000000                         7.000000
# 7                   0.750000                         4.250000
# 8                   2.666667                         3.500000
# 9                   2.750000                         5.250000
# 10                  2.933333                         4.800000
# 11                  3.800000                         4.933333
# 12                  4.444444                         5.666667
# 13                  4.000000                         6.000000
# 14                  0.500000                         5.500000
# 15                  0.500000                         1.625000
# 16                  0.500000                         4.000000
# 17                  4.933333                         4.933333
# 18                  1.600000                         3.400000
# 19                  0.000000                         1.800000
# 20                  0.000000                         5.400000
# 21                  2.500000                         5.333333
# 22                  4.800000                         4.800000
# 23                  0.533333                         4.133333
# 24                  4.933333                         4.933333
# 25                  2.333333                         6.000000
# 26                  2.250000                         4.625000
# 27                  4.133333                         4.666667
# 28                  4.333333                         4.800000
# 29                  0.000000                         1.538462
# ...                      ...                              ...
# 134962              4.000000                         5.600000
# 134963              0.466667                         4.800000
# 134964              4.533333                         4.933333
# 134965              4.000000                         7.000000
# 134966              3.666667                         6.000000
# 134967              4.333333                         4.933333
# 134968              1.083333                         2.666667
# 134969              3.500000                         3.500000
# 134970              1.000000                         5.750000
# 134971              0.000000                         0.000000
# 134972              6.500000                         6.500000
# 134973              4.800000                         4.933333
# 134974              2.000000                         7.000000
# 134975              5.500000                         5.500000
# 134976              0.000000                         6.000000
# 134977              4.000000                         4.933333
# 134978              4.600000                         7.800000
# 134979              4.933333                         4.933333
# 134980              4.800000                         5.933333
# 134981              0.666667                         6.000000
# 134982              4.461538                         4.692308
# 134983              4.866667                         4.933333
# 134984              4.500000                         5.166667
# 134985              0.500000                         3.000000
# 134986              3.714286                         4.785714
# 134987              0.785714                         2.214286
# 134988              2.200000                         5.000000
# 134989              0.400000                         5.000000
# 134990              4.933333                         4.933333
# 134991              4.200000                         4.800000
#
#         num_videos_rated
# 0               0.000000
# 1               0.000000
# 2               0.000000
# 3               0.000000
# 4               0.000000
# 5               0.066667
# 6               0.000000
# 7               0.000000
# 8               0.000000
# 9               0.000000
# 10              0.000000
# 11              0.000000
# 12              0.000000
# 13              0.000000
# 14              0.000000
# 15              0.000000
# 16              0.000000
# 17              0.000000
# 18              0.000000
# 19              0.000000
# 20              0.000000
# 21              0.000000
# 22              0.133333
# 23              0.000000
# 24              0.000000
# 25              0.000000
# 26              0.000000
# 27              0.000000
# 28              0.066667
# 29              0.000000
# ...                  ...
# 134962          0.000000
# 134963          0.000000
# 134964          0.000000
# 134965          0.000000
# 134966          0.000000
# 134967          0.000000
# 134968          0.000000
# 134969          0.000000
# 134970          0.000000
# 134971          0.000000
# 134972          0.000000
# 134973          0.000000
# 134974          0.000000
# 134975          0.000000
# 134976          0.000000
# 134977          0.000000
# 134978          0.000000
# 134979          0.000000
# 134980          0.000000
# 134981          0.000000
# 134982          0.000000
# 134983          0.000000
# 134984          0.000000
# 134985          0.000000
# 134986          0.000000
# 134987          0.000000
# 134988          0.000000
# 134989          0.000000
# 134990          0.000000
# 134991          0.000000
#
# [134992 rows x 7 columns]

# %% [markdown]
# #### 1.4 Dataset-Combination for churn modeling (Only useful features from three dataset)

# %%
customer.columns
# Out:
# Index(['subid', 'package_type', 'num_weekly_services_utilized',
#        'preferred_genre', 'intended_use', 'weekly_consumption_hour',
#        'num_ideal_streaming_services', 'retarget_TF', 'age', 'male_TF',
#        'country', 'attribution_technical', 'attribution_survey', 'op_sys',
#        'months_per_bill_period', 'plan_type', 'monthly_price',
#        'discount_price', 'account_creation_date', 'creation_until_cancel_days',
#        'cancel_before_trial_end', 'trial_end_date',
#        'initial_credit_card_declined', 'revenue_net', 'join_fee', 'language',
#        'paid_TF', 'refund_after_trial_TF', 'payment_type'],
#       dtype='object')

# %%
meaningful_features=['subid','package_type', 'preferred_genre', 'intended_use', 'plan_type',
                     'weekly_consumption_hour', 'age', 'male_TF', 'attribution_technical', 
                    'attribution_survey', 'cancel_before_trial_end', 'revenue_net', 'join_fee']

customer_with_meaningful_feature = customer[meaningful_features]

for i in meaningful_features:
    print(i)
    print(sum(customer_with_meaningful_feature[i].isnull()))
# Out:
# subid
# 0
# package_type
# 35574
# preferred_genre
# 36326
# intended_use
# 3549
# plan_type
# 0
# weekly_consumption_hour
# 37930
# age
# 35169
# male_TF
# 269
# attribution_technical
# 0
# attribution_survey
# 2644
# cancel_before_trial_end
# 0
# revenue_net
# 34904
# join_fee
# 34904

# %%
#fill null category features with 'unknown'
customer_with_meaningful_feature['package_type'] = customer_with_meaningful_feature['package_type'].fillna('Unknown')
customer_with_meaningful_feature['preferred_genre'] = customer_with_meaningful_feature['preferred_genre'].fillna('Unknown')
customer_with_meaningful_feature['intended_use'] = customer_with_meaningful_feature['intended_use'].fillna('Unknown')
customer_with_meaningful_feature['male_TF'] = customer_with_meaningful_feature['male_TF'].fillna('Unknown')
customer_with_meaningful_feature['attribution_survey'] = customer_with_meaningful_feature['attribution_survey'].fillna('Unknown')

#fill null numeric features with 0
customer_with_meaningful_feature['revenue_net'] = customer_with_meaningful_feature['revenue_net'].fillna(0)
customer_with_meaningful_feature['join_fee'] = customer_with_meaningful_feature['join_fee'].fillna(0)

#fill unknown age and weekly_consumption_hour with 0 and add_a_remark_column
customer_with_meaningful_feature['age_null'] = customer_with_meaningful_feature['revenue_net'].isnull()
customer_with_meaningful_feature['consumption_hour_null'] = customer_with_meaningful_feature['weekly_consumption_hour'].isnull()

customer_with_meaningful_feature['age'] = customer_with_meaningful_feature['age'].fillna(0)
customer_with_meaningful_feature['weekly_consumption_hour'] = customer_with_meaningful_feature['weekly_consumption_hour'].fillna(0)

customer_with_meaningful_feature
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#            subid package_type preferred_genre                 intended_use  \
# 162502  21724479      economy          comedy  access to exclusive content
# 380374  23383224         base          comedy  access to exclusive content
# 496617  26844789     enhanced        regional                  replace OTT
# 356799  29417030         base           drama                  replace OTT
# 681701  26723159         base          comedy                  replace OTT
# 284782  24810928         base          comedy  access to exclusive content
# 192823  29726122         base          comedy  access to exclusive content
# 315863  20299962         base           drama  access to exclusive content
# 254782  24930568         base          comedy  access to exclusive content
# 681969  23452753      economy           drama                  replace OTT
# 99989   21191741      Unknown         Unknown       expand regional access
# 290426  21361112     enhanced          comedy  access to exclusive content
# 277565  25393847         base        regional               supplement OTT
# 377093  23163827      economy          comedy                  replace OTT
# 546210  26308559      Unknown         Unknown  expand international access
# 143042  26874196         base          comedy  access to exclusive content
# 626743  27648682     enhanced          comedy                  replace OTT
# 673104  21829221     enhanced          comedy                  replace OTT
# 349365  29090912         base           drama               supplement OTT
# 598759  21760199      Unknown         Unknown  expand international access
# 208223  21511732     enhanced          comedy                  replace OTT
# 384799  22090440         base           drama  access to exclusive content
# 386250  28863903         base           drama                  replace OTT
# 7506    29576692      Unknown         Unknown  expand international access
# 389385  23676530         base          comedy  access to exclusive content
# 338592  26520640     enhanced           drama  access to exclusive content
# 343642  29773460         base          comedy  access to exclusive content
# 290800  20668260      economy           drama  access to exclusive content
# 179332  21447938         base           drama                  replace OTT
# 216541  25575254      economy          comedy  access to exclusive content
# ...          ...          ...             ...                          ...
# 582992  28111970     enhanced          comedy  access to exclusive content
# 117388  27161457         base           drama  access to exclusive content
# 627527  20483363     enhanced          comedy  access to exclusive content
# 497110  28449035         base          comedy               supplement OTT
# 99888   29909208      Unknown         Unknown  expand international access
# 61453   26067054         base           drama                  replace OTT
# 632153  24614848         base        regional                  replace OTT
# 120555  24315621         base          comedy                  replace OTT
# 1384    25927672      Unknown         Unknown       expand regional access
# 354013  26509361     enhanced          comedy                  replace OTT
# 157820  29190645     enhanced          comedy  access to exclusive content
# 39499   22532282         base          comedy                  replace OTT
# 110393  26263998      Unknown         Unknown  expand international access
# 33596   26891485     enhanced          comedy                  replace OTT
# 60056   21731043     enhanced          comedy               supplement OTT
# 553731  20172551         base          comedy                  replace OTT
# 324200  24317364     enhanced          comedy                  replace OTT
# 254294  22117405         base          comedy  access to exclusive content
# 243775  26828621         base           drama  access to exclusive content
# 136817  28920930     enhanced        regional                  replace OTT
# 303902  22218943      economy          comedy                  replace OTT
# 378377  25492551         base          comedy  access to exclusive content
# 230734  21928274         base           drama                  replace OTT
# 577745  25549852     enhanced          comedy  access to exclusive content
# 603751  25835684         base           drama  access to exclusive content
# 509326  21434712     enhanced          comedy               supplement OTT
# 229587  25843074     enhanced          comedy                  replace OTT
# 281340  24799085         base          comedy  access to exclusive content
# 87198   21308040         base          comedy  access to exclusive content
# 598241  20166335         base          comedy                  replace OTT
#
#                     plan_type  weekly_consumption_hour   age male_TF  \
# 162502  base_uae_14_day_trial                 0.000000   0.0   False
# 380374  base_uae_14_day_trial                22.951579  70.0   False
# 496617  base_uae_14_day_trial                36.001186  25.0    True
# 356799  base_uae_14_day_trial                20.051667  30.0   False
# 681701  base_uae_14_day_trial                22.951579  28.0   False
# 284782  base_uae_14_day_trial                20.051667  70.0   False
# 192823  base_uae_14_day_trial                20.051667  61.0   False
# 315863  base_uae_14_day_trial                34.551230  23.0   False
# 254782  base_uae_14_day_trial                25.851492  73.0   False
# 681969  base_uae_14_day_trial                28.751405  71.0   False
# 99989   base_uae_14_day_trial                34.551230  53.0    True
# 290426  base_uae_14_day_trial                37.451142  24.0    True
# 277565  base_uae_14_day_trial                28.751405  57.0   False
# 377093  base_uae_14_day_trial                33.101274  54.0   False
# 546210  base_uae_14_day_trial                30.201361  48.0   False
# 143042  base_uae_14_day_trial                 0.000000   0.0   False
# 626743  base_uae_14_day_trial                27.301448  26.0   False
# 673104  base_uae_14_day_trial                27.301448  24.0   False
# 349365  base_uae_14_day_trial                37.451142  50.0   False
# 598759  base_uae_14_day_trial                30.201361  32.0   False
# 208223  base_uae_14_day_trial                27.301448  26.0   False
# 384799  base_uae_14_day_trial                22.951579  65.0   False
# 386250  base_uae_14_day_trial                21.501623  50.0   False
# 7506    base_uae_14_day_trial                34.551230  31.0   False
# 389385  base_uae_14_day_trial                24.401536  21.0   False
# 338592  base_uae_14_day_trial                24.401536  37.0   False
# 343642  base_uae_14_day_trial                 0.000000   0.0   False
# 290800  base_uae_14_day_trial                21.501623  49.0   False
# 179332  base_uae_14_day_trial                30.201361  59.0   False
# 216541  base_uae_14_day_trial                 0.000000   0.0   False
# ...                       ...                      ...   ...     ...
# 582992  base_uae_14_day_trial                28.751405  55.0   False
# 117388  base_uae_14_day_trial                 0.000000   0.0   False
# 627527  base_uae_14_day_trial                30.201361  36.0   False
# 497110  base_uae_14_day_trial                38.901099  45.0    True
# 99888   base_uae_14_day_trial                25.851492  19.0   False
# 61453   base_uae_14_day_trial                27.301448  55.0   False
# 632153  base_uae_14_day_trial                25.851492  36.0   False
# 120555  base_uae_14_day_trial                 0.000000   0.0   False
# 1384    base_uae_14_day_trial                30.201361  34.0   False
# 354013  base_uae_14_day_trial                33.101274  57.0   False
# 157820  base_uae_14_day_trial                25.851492  46.0   False
# 39499   base_uae_14_day_trial                 0.000000   0.0   False
# 110393  base_uae_14_day_trial                -8.947459  43.0   False
# 33596   base_uae_14_day_trial                 0.000000   0.0   False
# 60056   base_uae_14_day_trial                28.751405  55.0   False
# 553731  base_uae_14_day_trial                21.501623  45.0   False
# 324200  base_uae_14_day_trial                30.201361  52.0   False
# 254294  base_uae_14_day_trial                24.401536  30.0   False
# 243775  base_uae_14_day_trial                27.301448  44.0   False
# 136817  base_uae_14_day_trial                 0.000000   0.0   False
# 303902  base_uae_14_day_trial                37.451142  67.0    True
# 378377  base_uae_14_day_trial                30.201361  32.0   False
# 230734  base_uae_14_day_trial                 0.000000   0.0   False
# 577745  base_uae_14_day_trial                28.751405  61.0   False
# 603751  base_uae_14_day_trial                24.401536  43.0   False
# 509326  base_uae_14_day_trial                28.751405  38.0   False
# 229587  base_uae_14_day_trial                27.301448  49.0   False
# 281340  base_uae_14_day_trial                31.651317  45.0   False
# 87198   base_uae_14_day_trial                 0.000000   0.0   False
# 598241  base_uae_14_day_trial                25.851492  55.0   False
#
#           attribution_technical attribution_survey  cancel_before_trial_end  \
# 162502                 facebook           facebook                     True
# 380374                 facebook           facebook                    False
# 496617                  organic           facebook                    False
# 356799                   search                 tv                    False
# 681701                discovery            youtube                    False
# 284782                     bing                 tv                     True
# 192823                     bing             search                     True
# 315863                    email           referral                     True
# 254782                 facebook           facebook                    False
# 681969                   search           facebook                    False
# 99989                   organic       public_radio                     True
# 290426                   search             search                    False
# 277565  brand sem intent google                 tv                    False
# 377093                 facebook           facebook                    False
# 546210           google_organic           facebook                    False
# 143042                 facebook           facebook                     True
# 626743                   search             search                    False
# 673104           google_organic           facebook                    False
# 349365                 facebook           facebook                    False
# 598759                    email           facebook                    False
# 208223                  organic           referral                     True
# 384799                 facebook                 tv                    False
# 386250                 facebook           facebook                    False
# 7506    brand sem intent google           facebook                     True
# 389385                  organic            youtube                    False
# 338592                 facebook           facebook                    False
# 343642                  organic           facebook                     True
# 290800                 facebook           facebook                     True
# 179332                  display           facebook                     True
# 216541                 facebook           facebook                     True
# ...                         ...                ...                      ...
# 582992                 facebook           facebook                    False
# 117388                 facebook           facebook                     True
# 627527                 referral           facebook                    False
# 497110                    email           facebook                    False
# 99888                  internal     social_organic                     True
# 61453                  internal                 tv                     True
# 632153                 facebook           facebook                    False
# 120555                 facebook           facebook                     True
# 1384                   internal                 tv                     True
# 354013                 facebook           facebook                    False
# 157820                   search     social_organic                     True
# 39499                  facebook           facebook                     True
# 110393                affiliate                 tv                     True
# 33596                    search           facebook                     True
# 60056                     email           facebook                     True
# 553731                 facebook           facebook                    False
# 324200                 facebook           facebook                    False
# 254294                  youtube           facebook                     True
# 243775                    email           facebook                     True
# 136817                    email           facebook                     True
# 303902    brand sem intent bing           referral                    False
# 378377                    email           facebook                    False
# 230734                 facebook           facebook                     True
# 577745                affiliate           facebook                    False
# 603751                    email          pinterest                    False
# 509326                 facebook   facebook_organic                    False
# 229587           google_organic           referral                     True
# 281340                 facebook           facebook                     True
# 87198                  facebook           facebook                     True
# 598241                  organic                 tv                    False
#
#         revenue_net  join_fee  age_null  consumption_hour_null
# 162502       0.0000    0.0000     False                   True
# 380374       0.0000    0.3303     False                  False
# 496617       0.0000    0.1101     False                  False
# 356799       0.0000    0.0367     False                  False
# 681701       0.0000    0.0367     False                  False
# 284782       0.0000    0.3303     False                  False
# 192823       4.5875    0.3303     False                  False
# 315863       3.4498    0.0000     False                  False
# 254782       0.0000    0.6606     False                  False
# 681969       0.0000    0.3303     False                  False
# 99989        9.2117    0.0367     False                  False
# 290426       0.0000    0.3303     False                  False
# 277565       0.0000    0.0367     False                  False
# 377093       0.0000    0.0367     False                  False
# 546210       0.0000    0.0367     False                  False
# 143042       0.0000    0.0000     False                   True
# 626743       0.0000    0.0367     False                  False
# 673104       0.0000    0.0367     False                  False
# 349365       0.0000    0.0367     False                  False
# 598759       0.0000    0.0000     False                  False
# 208223       3.2296    0.0367     False                  False
# 384799       0.0000    0.3303     False                  False
# 386250       0.0000    0.3303     False                  False
# 7506         1.6148    0.0367     False                  False
# 389385       0.0000    0.3303     False                  False
# 338592       0.0000    0.6606     False                  False
# 343642       0.0000    0.0000     False                   True
# 290800       0.0000    0.1101     False                  False
# 179332       4.5875    0.3303     False                  False
# 216541       0.0000    0.0000     False                   True
# ...             ...       ...       ...                    ...
# 582992       0.0000    0.0367     False                  False
# 117388       0.0000    0.0000     False                   True
# 627527       0.0000    0.0367     False                  False
# 497110       0.0000    0.0000     False                  False
# 99888        7.4134    0.0000     False                  False
# 61453        5.0279    0.0367     False                  False
# 632153       0.0000    0.1101     False                  False
# 120555       0.0000    0.0000     False                   True
# 1384         4.5875    0.0367     False                  False
# 354013       0.0000    0.0367     False                  False
# 157820       4.5875    0.3303     False                  False
# 39499        0.0000    0.0000     False                   True
# 110393       0.0000    0.0367     False                  False
# 33596        0.0000    0.0000     False                   True
# 60056        9.7622    0.0000     False                  False
# 553731       0.0000    0.0367     False                  False
# 324200       0.0000    0.0367     False                  False
# 254294       0.0000    0.0367     False                  False
# 243775      -0.6973    0.0000     False                  False
# 136817       0.0000    0.0000     False                   True
# 303902       0.0000    0.0367     False                  False
# 378377       0.0000    0.0000     False                  False
# 230734       0.0000    0.0000     False                   True
# 577745       0.0000    0.3303     False                  False
# 603751       0.0000    0.0000     False                  False
# 509326       0.0000    0.3303     False                  False
# 229587       4.5875    0.3303     False                  False
# 281340       0.0000    0.0367     False                  False
# 87198        0.0000    0.0000     False                   True
# 598241       0.0000    0.0367     False                  False
#
# [227628 rows x 15 columns]

# %%
for i in meaningful_features:
    print(i)
    print(sum(customer_with_meaningful_feature[i].isnull()))
# Out:
# subid
# 0
# package_type
# 0
# preferred_genre
# 0
# intended_use
# 0
# plan_type
# 0
# weekly_consumption_hour
# 0
# age
# 0
# male_TF
# 0
# attribution_technical
# 0
# attribution_survey
# 0
# cancel_before_trial_end
# 0
# revenue_net
# 0
# join_fee
# 0

# %%
#dataset.merge

modeling_dataset = pd.merge(customer_with_meaningful_feature, service_by_individual, on='subid', how='left')
modeling_dataset = pd.merge(modeling_dataset, engag_period_0_by_individual, on='subid', how='left')

modeling_dataset.shape
# Out:
# (227628, 26)

# %%
modeling_dataset = modeling_dataset.dropna(axis=0)

modeling_dataset.shape
# Out:
# (134992, 26)

# %%
modeling_dataset['current_sub_TF'].value_counts()
# Out:
# False    102652
# True      32340
# Name: current_sub_TF, dtype: int64

# %% [markdown]
# ##### comparted two features indicate if customer finished free_trial

# %%
modeling_dataset[['cancel_before_trial_end', 'trial_completed_TF']].head()
# Out:
#     cancel_before_trial_end trial_completed_TF
# 2                     False              False
# 6                      True               True
# 7                      True               True
# 8                     False              False
# 11                    False              False

# %%
sum(modeling_dataset['cancel_before_trial_end'] == modeling_dataset['trial_completed_TF'])
# Out:
# 134992

# %%
modeling_dataset.drop(['cancel_before_trial_end'], axis=1, inplace=True)

# %%
modeling_dataset_after_trial = modeling_dataset[modeling_dataset['trial_completed_TF']==True]

modeling_dataset_after_trial.shape
# Out:
# (62347, 25)

# %% [markdown]
# ### Task 1: A-B Testing

# %%
def t_test_1(A,B, alpha):
    
    x1 = np.mean(A)
    x2 = np.mean(B)
    p = (np.sum(A)+np.sum(B))/(len(A)+len(B))
    
    t = (x2-x1)/(np.sqrt(p*(1-p)*(1/len(A)+1/len(B))))
    
    critical_value = stats.t.ppf((1-alpha),(len(A)+len(B)-2))
    print(t)
    if np.abs(t) >= critical_value:
        print('reject null hypothesis with confidence interval of {}'.format(1-alpha))
    else:
        print('not reject null hypothesis with confidence interval of {}'.format(1-alpha))

# %%
customer['plan_type'].value_counts()
# Out:
# base_uae_14_day_trial                227096
# high_uae_14_day_trial                   325
# low_uae_no_trial                        167
# base_eur_14_day_trial                    18
# high_sar_14_day_trial                    12
# low_gbp_14_day_trial                      4
# high_aud_14_day_trial                     2
# low_eur_no_trial                          1
# high_jpy_14_day_trial                     1
# base_uae_no_trial_7_day_guarantee         1
# low_sar_no_trial                          1
# Name: plan_type, dtype: int64

# %%
list_A = list(customer.loc[customer['plan_type']=='base_uae_14_day_trial', 'cancel_before_trial_end'])

list_B = list(customer.loc[customer['plan_type']=='low_uae_no_trial', 'cancel_before_trial_end'])

list_C = list(customer.loc[customer['plan_type']=='high_uae_14_day_trial', 'cancel_before_trial_end'])

# %%
t_test_1(list_A, list_B, 0.01)
# Out:
# 10.108042393707912
# reject null hypothesis with confidence interval of 0.99

# %%
t_test_1(list_B, list_C, 0.01)
# Out:
# -8.776227193493403
# reject null hypothesis with confidence interval of 0.99

# %%
t_test_1(list_A, list_C, 0.05)
# Out:
# -0.8645877257715118
# not reject null hypothesis with confidence interval of 0.95

# %% [markdown]
# ### Task 2: Customer Segmentation

# %%
customer_for_cluster = customer[['preferred_genre',  'male_TF', 'age']]

customer_for_cluster = customer_for_cluster[customer_for_cluster['age']<=100]


customer_dummy = pd.get_dummies(customer_for_cluster)

customer_dummy
# Out:
#          age  preferred_genre_comedy  preferred_genre_drama  \
# 380374  70.0                       1                      0
# 496617  25.0                       0                      0
# 356799  30.0                       0                      1
# 681701  28.0                       1                      0
# 284782  70.0                       1                      0
# 192823  61.0                       1                      0
# 315863  23.0                       0                      1
# 254782  73.0                       1                      0
# 681969  71.0                       0                      1
# 99989   53.0                       0                      0
# 290426  24.0                       1                      0
# 277565  57.0                       0                      0
# 377093  54.0                       1                      0
# 546210  48.0                       0                      0
# 626743  26.0                       1                      0
# 673104  24.0                       1                      0
# 349365  50.0                       0                      1
# 598759  32.0                       0                      0
# 208223  26.0                       1                      0
# 384799  65.0                       0                      1
# 386250  50.0                       0                      1
# 7506    31.0                       0                      0
# 389385  21.0                       1                      0
# 338592  37.0                       0                      1
# 290800  49.0                       0                      1
# 179332  59.0                       0                      1
# 435503  29.0                       0                      1
# 420126  61.0                       0                      0
# 161     48.0                       0                      0
# 110387  35.0                       0                      0
# ...      ...                     ...                    ...
# 514152  59.0                       0                      0
# 329584  26.0                       1                      0
# 33320   46.0                       0                      0
# 428794  45.0                       1                      0
# 447297  50.0                       1                      0
# 338767  30.0                       0                      0
# 35318   25.0                       0                      0
# 582992  55.0                       1                      0
# 627527  36.0                       1                      0
# 497110  45.0                       1                      0
# 99888   19.0                       0                      0
# 61453   55.0                       0                      1
# 632153  36.0                       0                      0
# 1384    34.0                       0                      0
# 354013  57.0                       1                      0
# 157820  46.0                       1                      0
# 110393  43.0                       0                      0
# 60056   55.0                       1                      0
# 553731  45.0                       1                      0
# 324200  52.0                       1                      0
# 254294  30.0                       1                      0
# 243775  44.0                       0                      1
# 303902  67.0                       1                      0
# 378377  32.0                       1                      0
# 577745  61.0                       1                      0
# 603751  43.0                       0                      1
# 509326  38.0                       1                      0
# 229587  49.0                       1                      0
# 281340  45.0                       1                      0
# 598241  55.0                       1                      0
#
#         preferred_genre_international  preferred_genre_other  \
# 380374                              0                      0
# 496617                              0                      0
# 356799                              0                      0
# 681701                              0                      0
# 284782                              0                      0
# 192823                              0                      0
# 315863                              0                      0
# 254782                              0                      0
# 681969                              0                      0
# 99989                               0                      0
# 290426                              0                      0
# 277565                              0                      0
# 377093                              0                      0
# 546210                              0                      0
# 626743                              0                      0
# 673104                              0                      0
# 349365                              0                      0
# 598759                              0                      0
# 208223                              0                      0
# 384799                              0                      0
# 386250                              0                      0
# 7506                                0                      0
# 389385                              0                      0
# 338592                              0                      0
# 290800                              0                      0
# 179332                              0                      0
# 435503                              0                      0
# 420126                              0                      0
# 161                                 0                      0
# 110387                              0                      0
# ...                               ...                    ...
# 514152                              0                      1
# 329584                              0                      0
# 33320                               0                      0
# 428794                              0                      0
# 447297                              0                      0
# 338767                              1                      0
# 35318                               0                      0
# 582992                              0                      0
# 627527                              0                      0
# 497110                              0                      0
# 99888                               0                      0
# 61453                               0                      0
# 632153                              0                      0
# 1384                                0                      0
# 354013                              0                      0
# 157820                              0                      0
# 110393                              0                      0
# 60056                               0                      0
# 553731                              0                      0
# 324200                              0                      0
# 254294                              0                      0
# 243775                              0                      0
# 303902                              0                      0
# 378377                              0                      0
# 577745                              0                      0
# 603751                              0                      0
# 509326                              0                      0
# 229587                              0                      0
# 281340                              0                      0
# 598241                              0                      0
#
#         preferred_genre_regional  male_TF_False  male_TF_True
# 380374                         0              1             0
# 496617                         1              0             1
# 356799                         0              1             0
# 681701                         0              1             0
# 284782                         0              1             0
# 192823                         0              1             0
# 315863                         0              1             0
# 254782                         0              1             0
# 681969                         0              1             0
# 99989                          0              0             1
# 290426                         0              0             1
# 277565                         1              1             0
# 377093                         0              1             0
# 546210                         0              1             0
# 626743                         0              1             0
# 673104                         0              1             0
# 349365                         0              1             0
# 598759                         0              1             0
# 208223                         0              1             0
# 384799                         0              1             0
# 386250                         0              1             0
# 7506                           0              1             0
# 389385                         0              1             0
# 338592                         0              1             0
# 290800                         0              1             0
# 179332                         0              1             0
# 435503                         0              1             0
# 420126                         1              1             0
# 161                            1              1             0
# 110387                         0              0             1
# ...                          ...            ...           ...
# 514152                         0              1             0
# 329584                         0              1             0
# 33320                          0              1             0
# 428794                         0              1             0
# 447297                         0              1             0
# 338767                         0              1             0
# 35318                          0              1             0
# 582992                         0              1             0
# 627527                         0              1             0
# 497110                         0              0             1
# 99888                          0              1             0
# 61453                          0              1             0
# 632153                         1              1             0
# 1384                           0              1             0
# 354013                         0              1             0
# 157820                         0              1             0
# 110393                         0              1             0
# 60056                          0              1             0
# 553731                         0              1             0
# 324200                         0              1             0
# 254294                         0              1             0
# 243775                         0              1             0
# 303902                         0              0             1
# 378377                         0              1             0
# 577745                         0              1             0
# 603751                         0              1             0
# 509326                         0              1             0
# 229587                         0              1             0
# 281340                         0              1             0
# 598241                         0              1             0
#
# [191571 rows x 8 columns]

# %%
customer_seg = pd.merge(customer[['subid']], customer_dummy, left_index=True, right_index = True, how='left')

customer_seg.shape
# Out:
# (227628, 8)

# %%
customer_seg = pd.merge(customer_seg, engag_by_individual, on= 'subid', how='left')

customer_seg.shape
# Out:
# (227628, 14)

# %%
customer_seg.dropna(axis=0, inplace=True)
#customer_seg = customer_seg[customer_seg['age']<=100]

customer_seg.set_index('subid',inplace=True)

customer_seg.shape
# Out:
# (135019, 13)

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

def fitting(df):
    Sum_of_squared_distances = []
    K = range(1,15)
    for k in K:
        km = KMeans(n_clusters=k)
        km = km.fit(df)
        Sum_of_squared_distances.append(km.inertia_)
    plt.plot(K, Sum_of_squared_distances, 'bx-')
    plt.xlabel('k')
    plt.ylabel('Sum_of_squared_distances')
    plt.title('Elbow Method For Optimal k')
    plt.show()
    return

# %%
fitting(customer_seg)

# %%
kmeans = KMeans(n_clusters = 4, random_state=0).fit(customer_seg)

# %%
a = list(kmeans.cluster_centers_)

seg_result = pd.DataFrame(a, columns=customer_seg.columns)

seg_result
# Out:
#    preferred_genre_comedy  preferred_genre_drama  \
# 0                0.625535               0.191131
# 1                0.526574               0.183853
# 2                0.490148               0.190794
# 3                0.534729               0.198994
#
#    preferred_genre_international  preferred_genre_other  \
# 0                       0.021101               0.021101
# 1                       0.024514               0.018385
# 2                       0.025853               0.014187
# 3                       0.025929               0.015871
#
#    preferred_genre_regional  male_TF_False  male_TF_True  app_opens  \
# 0                  0.042431       0.912385      0.087615   5.417363
# 1                  0.038884       0.915633      0.084367   1.610344
# 2                  0.038936       0.869266      0.130734   0.983338
# 3                  0.039767       0.881377      0.118623   1.402847
#
#    cust_service_mssgs  num_series_started  num_videos_completed  \
# 0            0.649284            0.803955              3.807601
# 1            0.708815            0.666912              4.026078
# 2            0.542613            0.116279              0.571061
# 3            0.612289            0.338677              1.557104
#
#    num_videos_more_than_30_seconds  num_videos_rated
# 0                         4.864085          0.043627
# 1                         5.107256          0.039895
# 2                         2.774121          0.000768
# 3                         4.940268          0.007575

# %%
customer_dummy.dropna(axis=0, inplace=True)
customer_dummy

fitting(customer_dummy)

# %%
kmeans = KMeans(n_clusters = 3, random_state=0).fit(customer_dummy)

a = list(kmeans.cluster_centers_)

seg_result = pd.DataFrame(a, columns=customer_dummy.columns)

seg_result
# Out:
#          age  preferred_genre_comedy  preferred_genre_drama  \
# 0  47.012435                0.502941               0.198042
# 1  30.178994                0.557215               0.165237
# 2  63.625736                0.456716               0.274390
#
#    preferred_genre_international  preferred_genre_other  \
# 0                       0.030785               0.019216
# 1                       0.022967               0.019455
# 2                       0.043075               0.020770
#
#    preferred_genre_regional  male_TF_False  male_TF_True
# 0                  0.049806       0.872616      0.127345
# 1                  0.059449       0.874223      0.125777
# 2                  0.017245       0.863345      0.136636

# %% [markdown]
# ### Task 3: Churn Modeling

# %%
modeling_dataset_after_trial.head()
# Out:
#        subid package_type preferred_genre                 intended_use  \
# 6   29726122         base          comedy  access to exclusive content
# 7   20299962         base           drama  access to exclusive content
# 15  26874196         base          comedy  access to exclusive content
# 20  21511732     enhanced          comedy                  replace OTT
# 23  29576692      Unknown         Unknown  expand international access
#
#                 plan_type  weekly_consumption_hour   age male_TF  \
# 6   base_uae_14_day_trial                20.051667  61.0   False
# 7   base_uae_14_day_trial                34.551230  23.0   False
# 15  base_uae_14_day_trial                 0.000000   0.0   False
# 20  base_uae_14_day_trial                27.301448  26.0   False
# 23  base_uae_14_day_trial                34.551230  31.0   False
#
#       attribution_technical attribution_survey  ...  num_trial_days  \
# 6                      bing             search  ...            14.0
# 7                     email           referral  ...            14.0
# 15                 facebook           facebook  ...            14.0
# 20                  organic           referral  ...            14.0
# 23  brand sem intent google           facebook  ...            14.0
#
#     total_payment_periods  revenue_net_1month  trial_completed_TF app_opens  \
# 6                     2.0              4.5875                True  0.900000
# 7                     2.0              3.4498                True  3.400000
# 15                    2.0              4.5875                True  0.000000
# 20                    2.0              3.2296                True  2.400000
# 23                    2.0              4.5875                True  1.466667
#
#     cust_service_mssgs  num_series_started  num_videos_completed  \
# 6             0.900000            0.800000                   4.6
# 7             0.266667            0.933333                   4.4
# 15            2.000000            0.000000                   0.0
# 20            0.200000            0.200000                   0.8
# 23            0.800000            1.000000                   4.8
#
#    num_videos_more_than_30_seconds  num_videos_rated
# 6                         4.600000               0.0
# 7                         4.933333               0.0
# 15                        0.000000               0.0
# 20                        2.600000               0.0
# 23                        4.800000               0.0
#
# [5 rows x 25 columns]

# %%
modeling = modeling_dataset.copy()

dummy_list = ['package_type','preferred_genre','male_TF','intended_use', 'plan_type', 'attribution_technical', 'attribution_survey']

model_dummy = pd.get_dummies(modeling[dummy_list])

model_dummy.shape
# Out:
# (134992, 77)

# %%
modeling = modeling.drop(dummy_list, axis=1)

modeling = pd.merge(modeling, model_dummy, left_index=True, right_index = True, how='left')

modeling.shape
# Out:
# (134992, 95)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, f1_score, confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler

# %%
#split data into training (70%) and test (30%) data set
X_dataset = modeling.drop(['current_sub_TF','subid','revenue_net_1month','total_payment_periods', 'trial_completed_TF','revenue_net'], axis=1)
y_data = modeling['current_sub_TF']
y_data=y_data.astype('int')

scaler = StandardScaler()

scaler.fit(X_dataset)

# Apply the power transform to the data
normal_X = pd.DataFrame(scaler.transform(X_dataset), columns = X_dataset.columns,
                              index = X_dataset.index)


X_train, X_test, y_train, y_test = train_test_split(normal_X, y_data, random_state = 0, test_size = 0.3)

# %%
# built logisticregression model with C = [0.001, 0.1, 10, 1000], using cross validation to evaluate the models for contacted dataset
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import validation_curve
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

clf = LogisticRegression()

cv_scores = cross_val_score(clf, X_train, y_train, cv=3)  # parameter cv is number of folds you want to split

print('Cross-validation scores for contacted dataset (3-fold):', cv_scores)
print('Mean cross-validation score for contacted dataset (3-fold): {:.3f}'
     .format(np.mean(cv_scores)))

param_range = np.logspace(-3, 3, 4)
train_scores, test_scores = validation_curve(clf, X_train, y_train,
                                            param_name='C',
                                            param_range=param_range, cv=5)

print('Mean train cross-validation score (5-folds) for contacted dataset with C = [0.001, 0.1, 10, 1000]: {}'.format(np.mean(train_scores, axis=1)))
print('Mean test cross-validation score (5-folds) for contacted dataset with C = [0.001, 0.1, 10, 1000]: {}'.format(np.mean(test_scores, axis=1)))
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Cross-validation scores for contacted dataset (3-fold): [0.81983555 0.81335323 0.81842715]
# Mean cross-validation score for contacted dataset (3-fold): 0.817
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Mean train cross-validation score (5-folds) for contacted dataset with C = [0.001, 0.1, 10, 1000]: [0.81736936 0.81757572 0.81754662 0.81754397]
# Mean test cross-validation score (5-folds) for contacted dataset with C = [0.001, 0.1, 10, 1000]: [0.81660211 0.81694078 0.81684554 0.81684554]

# %%
from sklearn import metrics
def contacted_data_test(model):
    model.fit(X_train, y_train)
    #print("The coefficient of each independent variable is {}".format(model.coef_))
    print("The Mean test cross-validation score (5-folds) for contacted dataset: {}".format(np.mean(cross_val_score(model, X_train, y_train, cv=5))))

    prediction = model.predict(X_test)
    prob_log = model.predict_proba(X_test)[:,1]
    test_score = accuracy_score(y_test, prediction)
    print("The accuracy score for contacted dataset's test set: {}".format(test_score))

    CM = confusion_matrix(y_test,prediction)
    tn, fp, fn, tp = confusion_matrix(y_test, prediction).ravel()
    recall = tp/(tp+fn) #沒抓到
    precision = tp/(tp+fp) #抓錯
    print("Confusion matrix for the test set: {}".format(CM))
    print("TN: {} / FP: {} / FN: {} / TP: {}".format(tn, fp, fn, tp))
    print("Recall: {:.4f} / Precision: {:.4f}".format(recall, precision))
    
    print('AUC:{}'.format(metrics.roc_auc_score(y_test,prob_log)))

# %%
# use the best parameter to build the logistic regression model for contacted dataset, apply on the test data and get the accuracy score
clf = LogisticRegression(C=0.1)
contacted_data_test(clf)
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# The Mean test cross-validation score (5-folds) for contacted dataset: 0.8169407839529941
# The accuracy score for contacted dataset's test set: 0.8143612030223715
# Confusion matrix for the test set: [[28398  2408]
#  [ 5110  4582]]
# TN: 28398 / FP: 2408 / FN: 5110 / TP: 4582
# Recall: 0.4728 / Precision: 0.6555
# AUC:0.852135546299102

# %%
# built decision tree model with max_depth= [3,4,5,6,7], using cross validation to evaluate the models for contacted dataset

from sklearn.tree import DecisionTreeClassifier

dct = DecisionTreeClassifier(random_state=13)

cv_scores_4 = cross_val_score(dct, X_train, y_train, cv=3)  # parameter cv is number of folds you want to split

print('Cross-validation scores for contacted dataset(3-fold):', cv_scores_4)
print('Mean cross-validation score for contacted dataset(3-fold): {:.3f}'
     .format(np.mean(cv_scores_4)))

param_range = [3,4,5,6,7]
train_scores_2, test_scores_2 = validation_curve(dct, X_train, y_train,
                                            param_name='max_depth',
                                            param_range=param_range, cv=5)

print('Mean train cross-validation score (5-folds) for contacted dataset with max_depth = [3,4,5,6,7]: {}'.format(np.mean(train_scores_2, axis=1)))
print('Mean test cross-validation score (5-folds) for contacted dataset with max_depth = [3,4,5,6,7]: {}'.format(np.mean(test_scores_2, axis=1)))
# Out:
# Cross-validation scores for contacted dataset(3-fold): [0.77761199 0.77611277 0.77674064]
# Mean cross-validation score for contacted dataset(3-fold): 0.777
# Mean train cross-validation score (5-folds) for contacted dataset with max_depth = [3,4,5,6,7]: [0.81516023 0.8209463  0.82350466 0.83026965 0.8359208 ]
# Mean test cross-validation score (5-folds) for contacted dataset with max_depth = [3,4,5,6,7]: [0.81484543 0.82025319 0.82176654 0.82814785 0.83186239]

# %%
# use the best parameter to build the decision tree model for contacted dataset, apply on the test data and get the accuracy score
dct = DecisionTreeClassifier(random_state=13, max_depth=5)
contacted_data_test(dct)
# Out:
# The Mean test cross-validation score (5-folds) for contacted dataset: 0.8217665413840818
# The accuracy score for contacted dataset's test set: 0.8217195910909181
# Confusion matrix for the test set: [[28730  2076]
#  [ 5144  4548]]
# TN: 28730 / FP: 2076 / FN: 5144 / TP: 4548
# Recall: 0.4693 / Precision: 0.6866
# AUC:0.8369211414882944

# %%
feat_importances = pd.DataFrame(dct.feature_importances_, index=X_train.columns, 
                             columns=['importance']).sort_values('importance', ascending=False).head(10)

feat_importances
# Out:
#                                    importance
# age                                  0.577039
# num_series_started                   0.150272
# join_fee                             0.076034
# num_videos_more_than_30_seconds      0.065348
# cust_service_mssgs                   0.041266
# attribution_survey_facebook          0.040022
# package_type_Unknown                 0.020857
# num_videos_rated                     0.015167
# num_videos_completed                 0.004542
# attribution_technical_email_blast    0.002942

# %%
# built randomforest model with max_depth= [3,4,5], n_estimators = [13, 17, 20], max_features = [8,10,12,14], using gridsearch to evaluate the models for contacted dataset

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

rdf = RandomForestClassifier(random_state=1)

param_grid = [
    # try 24 (4×3×2) combinations of hyperparameters
    {'n_estimators': [50, 70], 'max_features': [10, 15], 'max_depth': [4,5,6]},
    # then try 6 (2×3) combinations with bootstrap set as False
    #{'bootstrap': [False], 'n_estimators': [5, 10], 'max_features': [2, 3, 4]},
  ]

grid_search = GridSearchCV(rdf, param_grid, cv=5, return_train_score=True)
grid_search.fit(X_train, y_train)

print(grid_search.best_params_)

print(grid_search.best_estimator_)

# display the test score for each parameter combination
cvres = grid_search.cv_results_
for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
    print(mean_score, params)
# Out:
# {'max_depth': 6, 'max_features': 15, 'n_estimators': 50}
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=6, max_features=15, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=50,
#                        n_jobs=None, oob_score=False, random_state=1, verbose=0,
#                        warm_start=False)
# 0.8070142019599128 {'max_depth': 4, 'max_features': 10, 'n_estimators': 50}
# 0.8078819819247783 {'max_depth': 4, 'max_features': 10, 'n_estimators': 70}
# 0.8091413211420831 {'max_depth': 4, 'max_features': 15, 'n_estimators': 50}
# 0.8090249116346011 {'max_depth': 4, 'max_features': 15, 'n_estimators': 70}
# 0.8095540457595192 {'max_depth': 5, 'max_features': 10, 'n_estimators': 50}
# 0.809522297712024 {'max_depth': 5, 'max_features': 10, 'n_estimators': 70}
# 0.814728977501217 {'max_depth': 5, 'max_features': 15, 'n_estimators': 50}
# 0.8140305204563253 {'max_depth': 5, 'max_features': 15, 'n_estimators': 70}
# 0.8124854488115647 {'max_depth': 6, 'max_features': 10, 'n_estimators': 50}
# 0.8126018583190467 {'max_depth': 6, 'max_features': 10, 'n_estimators': 70}
# 0.8210362562702394 {'max_depth': 6, 'max_features': 15, 'n_estimators': 50}
# 0.8205071221453214 {'max_depth': 6, 'max_features': 15, 'n_estimators': 70}

# %%
# use the best parameter to build the decision tree model for contacted dataset, apply on the test data and get the accuracy score
rdf = RandomForestClassifier(random_state=1, max_depth= 6, max_features= 15, n_estimators= 50)
contacted_data_test(rdf)
# Out:
# The Mean test cross-validation score (5-folds) for contacted dataset: 0.8210363204978741
# The accuracy score for contacted dataset's test set: 0.8184848634500469
# Confusion matrix for the test set: [[28326  2480]
#  [ 4871  4821]]
# TN: 28326 / FP: 2480 / FN: 4871 / TP: 4821
# Recall: 0.4974 / Precision: 0.6603
# AUC:0.8669083235978735

# %%
feat_importances = pd.DataFrame(rdf.feature_importances_, index=X_train.columns, 
                             columns=['importance']).sort_values('importance', ascending=False).head(10)

feat_importances
# Out:
#                                  importance
# consumption_hour_null              0.195445
# weekly_consumption_hour            0.157350
# age                                0.146325
# num_series_started                 0.131260
# num_videos_more_than_30_seconds    0.081592
# join_fee                           0.076309
# cust_service_mssgs                 0.033781
# attribution_survey_facebook        0.027160
# num_videos_rated                   0.023315
# package_type_Unknown               0.020757

# %%
params = {'figure.figsize': (9,6),
          "font.size" : 16,
          'axes.labelsize': 20,
          'axes.titlesize': 20,
          'xtick.labelsize': 16,
          'ytick.labelsize': 16,
          'legend.fontsize': 15}
plt.rcParams.update(params)

# %%
width = 0.5
plt.figure(figsize=(10,6))
plt.barh(feat_importances.index, feat_importances['importance'], color='#af4345')
plt.gca().invert_yaxis()
plt.show()
